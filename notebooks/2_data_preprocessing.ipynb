# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# In this notebook, I will reshape data to make if appropriate to perform social network analysis.

# %% [markdown]
# ### Import libraries

# %% [markdown]
# #### Basic libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import math
from collections import Counter
import gzip
import re
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# #### Network analysis and Network data visualization

# %%
import networkx as nx
import itertools
import os
from pyvis.network import Network

# %% [markdown]
# #### Profane language detection library

# %%
import sklearn.externals as extjoblib
import joblib
from profanity_check import predict, predict_prob

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('../data/chat_preprocessed.csv')
df
# Out:
#         match_id                   unit  pf
# 0              0              6k Slayer   1
# 1              0               Double T   1
# 2              0                   Kira   0
# 3              0                 Monkey   1
# 4              0               Trash!!!   0
# ...          ...                    ...  ..
# 303878     49771         DamN.Sakura_Jr   0
# 303879     49771                  Dante   0
# 303880     49771              PINAGPALA   1
# 303881     49771            StopDancing   0
# 303882     49771  WorstDayOfMyLife^Ever   0
#
# [303883 rows x 3 columns]

# %% [markdown]
# ## Find users who played more than 10 matches

# %% [markdown]
# ### Player's number of match `id` : `number of matches played`

# %%
id_count = Counter(df['unit'])
id_count
# Out:
# Counter({'6k Slayer': 1,
#          'Double T': 2,
#          'Kira': 25,
#          'Monkey': 12,
#          'Trash!!!': 1,
#          'u didnt see who highest here?': 1,
#          'ｔｏｍｉａ～♥': 1,
#          "Apin's": 1,
#          'Buk lau': 1,
#          'D o r a': 1,
#          'DA BOSS': 3,
#          'Titus': 7,
#          'stormX---': 1,
#          'Anonymous': 30,
#          'BlackJack': 3,
#          'Grötenelch': 1,
#          'KaLixz': 1,
#          'Star': 4,
#          'WtW|Tweedle Dee & Tweedle Dum': 1,
#          'Ａｌｉｃｅ': 1,
#          'AresStar®': 1,
#          'Arhey': 1,
#          'Arsich': 1,
#          'Fuck_Off': 4,
#          'Matt': 21,
#          'Porucznik Ku®wa': 5,
#          'ahohuhahohu': 1,
#          '¡No pasarán!': 1,
#          'Desolation': 5,
#          'FREAKGANG.haa': 1,
#          'SIMBA': 1,
#          'iceiceBABE': 1,
#          '$uƒfer': 2,
#          'Xiiao_Hung_': 2,
#          'stadin.xxx': 1,
#          'Ｌｕｉｓ': 2,
#          'Faint': 2,
#          'Jim Jim': 1,
#          'Ravenclaw': 2,
#          'qwewqewqewqewq': 1,
#          'ART': 6,
#          'ForTheWatch': 1,
#          'Hopelessly Confused': 3,
#          'I JUST FUCKED YOUR MOM': 1,
#          'Reega.mQuse': 1,
#          'melissachan♥': 11,
#          'ЛАКЕР': 1,
#          '6opuc_6puTBa': 1,
#          'BALTAZAR': 1,
#          'Kenny': 11,
#          'Memento Morte': 2,
#          'ShakeEyes': 1,
#          'ŞńèĞħõĶ': 1,
#          'НовыйПират': 1,
#          'ШУТНИК': 1,
#          '=DOC=Nobody': 1,
#          "GON#V4K1L //deadpool's brother": 1,
#          'Jason Todd': 1,
#          'Pittiplatsch der Liebe': 2,
#          'XaTiKo': 1,
#          'afroprogger': 1,
#          'Паша Бумчик': 1,
#          'Псих': 4,
#          'Makaveli': 8,
#          'Speedy': 4,
#          '★Chapa': 1,
#          '★RIZoN': 1,
#          'Doug Carl': 14,
#          'Hitmania2015 to 4k': 1,
#          'Punch you right in the mememake': 7,
#          'Will Lick Starfish For MMR': 5,
#          '俄艾勒吴和': 1,
#          'KingJonesGaming': 15,
#          'Klubdog': 5,
#          'Max Tryhard': 31,
#          'SiLvoS': 5,
#          'bourgeoisie': 38,
#          'depression': 1,
#          'soiforyou': 5,
#          'xela': 1,
#          'C@M@REN@': 1,
#          'Dark_Knight': 1,
#          'GM.mitology': 1,
#          'HybridTracer': 3,
#          'Kyu': 3,
#          "Mojava's Alt": 1,
#          'ReadY Go Go Go!!!!!!': 3,
#          'Standin.NerdsWrath': 2,
#          'Joe': 13,
#          'RAKOVINA': 1,
#          'Zmeik@': 1,
#          '| RaY |': 1,
#          'Egocard': 1,
#          'Eran': 2,
#          'GG-TubeRider!': 1,
#          'SavageClown': 1,
#          'God Bless': 4,
#          'Hades': 19,
#          'Los Mats': 3,
#          'OnE': 1,
#          'Tyr': 3,
#          'asianskater2004': 1,
#          'kamashiro': 1,
#          'london never': 1,
#          'ChickenNugget': 1,
#          'GoodGood': 3,
#          'Newbie': 7,
#          'Porky': 4,
#          'TimeToChange': 1,
#          'Winter-B': 3,
#          'de-rank dan': 1,
#          'toast': 5,
#          '-Haki-': 5,
#          '17% broken hero': 1,
#          'Masi': 6,
#          'T.O.P': 6,
#          'bowser': 1,
#          'gale gendale': 1,
#          'ебать': 13,
#          '♥♥♥': 1,
#          'SYBERIA': 1,
#          'Twitch.tv/FadiFlashi': 1,
#          'Twitch.tv/Vroksnak': 1,
#          'ЗА КАЗ МОДАН': 1,
#          '@ｇｕｃｃｉ': 2,
#          'Apple Juniper': 2,
#          'GWen': 6,
#          'Squawsh': 4,
#          'zwl': 1,
#          'zzzz': 4,
#          '关公不睁眼': 5,
#          '吃人': 4,
#          'BurnChezz': 3,
#          'LukaBear': 2,
#          'TurboS': 2,
#          'kangstag': 1,
#          '岳父国土': 1,
#          'HedAbDizPiley': 3,
#          'InFlames': 2,
#          'NEMESIS': 2,
#          'mitroshYk': 1,
#          'thevulturee': 1,
#          'АКАКИЙ': 2,
#          '@preuve': 1,
#          'Brudi': 1,
#          'GipsyMickey': 1,
#          'Hüwi': 1,
#          'so fucking bad': 1,
#          'АмиД.2.2.8.': 1,
#          'Berndt und das NACKT': 1,
#          'Mithrandir': 13,
#          "Prince of Qul'Thalas": 1,
#          'QolO': 1,
#          'Uchiha Itachi': 5,
#          '╠v╣ Typhus': 1,
#          '╠v╣AndySixx': 1,
#          'AA': 18,
#          'Bruce Wayne': 17,
#          'Gregor': 4,
#          'MV.Disable': 3,
#          'Totoy GOLEM': 1,
#          'qwela': 1,
#          'Cloude': 1,
#          'DayWalker': 3,
#          'Lalala': 5,
#          'mellojul': 2,
#          'z1g': 1,
#          '†': 14,
#          '"SS"': 1,
#          'Baz_laiter_': 1,
#          'R E D N A T I O N': 3,
#          'Twinkle': 1,
#          '[Black]Mr.Crackツ': 1,
#          'HOLY PEPERONI': 2,
#          'Le Chiffre': 7,
#          'RealOFF': 1,
#          'osad': 1,
#          '-4Head-': 1,
#          'Juan': 3,
#          'Kai': 22,
#          'Sleepy Hollow': 1,
#          'YUCKFOUMERYVUCH': 6,
#          'balow': 1,
#          'baopao': 1,
#          'cK.1': 10,
#          'shibui': 19,
#          '龘龖': 1,
#          'B.A.D-""GeeK""': 1,
#          'Liuke [?]': 1,
#          'Maiku Mori': 25,
#          'GrossmeisteR': 1,
#          'proshka jack': 1,
#          'КУ КУ ЁПТА': 1,
#          'ТОТ САМЫЙ': 2,
#          'Я ем жёпы': 1,
#          'ALWAYSWANNADIE': 12,
#          'Catnip': 6,
#          'Cheoklate': 9,
#          'GGWP': 22,
#          'JAMES IS REAL </3': 1,
#          'Orb of Venom': 1,
#          'Tin': 3,
#          'asdMM': 1,
#          'ezbreezy': 1,
#          'the Mogget': 1,
#          '+xXx+': 1,
#          'BrianCooper1': 13,
#          'FIRE': 6,
#          'GeniusY.': 1,
#          'Zippy': 3,
#          'NNNEEELLL': 1,
#          'Pskin': 1,
#          'REDHAIR': 1,
#          'Cocaine Bear': 1,
#          'DarK LighT': 4,
#          'Eclair': 1,
#          'KarozaTheDreamer': 2,
#          'Kعֆ╠╣Ꭿ™': 1,
#          'Mality': 1,
#          'Rymbas': 1,
#          'Stimpy': 3,
#          'chontofalsky': 1,
#          'Curlycore': 1,
#          'EternalMiracle': 1,
#          'PewPew': 8,
#          'burzum': 2,
#          'telefunken': 2,
#          'yellow flash': 1,
#          'DOC': 1,
#          'Kappa': 50,
#          'Lef': 1,
#          'Lorna Fume': 1,
#          'Nike <3': 3,
#          'NtNp[KingSize]': 2,
#          'Razvalution': 1,
#          '♥ jôjô ♥ツ': 3,
#          '1337 0tvertQa s0oQa': 1,
#          'Bophap': 2,
#          'IceFrog': 4,
#          'Marshall': 8,
#          'Monkey Business': 1,
#          'Самаясексиняшка!': 2,
#          'Bob Ross': 100,
#          'CinnamonSlut': 5,
#          'Phaeleh': 1,
#          'Willie Stroker': 1,
#          '[Homunkulus]': 1,
#          '[Hotte der Bauerntölpel]': 1,
#          '+ DeN +': 1,
#          'Luka': 2,
#          'k!$t!@n': 1,
#          '|||S|||E|||G|||A|||': 2,
#          'Алёша Блеать': 1,
#          'Весь мир идет на �': 1,
#          'AGREEBI 827 NG09': 1,
#          'MY LIFE FOR AIUR!!!!!!': 1,
#          'Naxus': 1,
#          'v2': 1,
#          'K-Prime': 3,
#          'Reza': 7,
#          'SmAsH': 2,
#          'Yyh': 2,
#          'iLLboRn': 1,
#          'mefartudie': 1,
#          'ØMyrm': 8,
#          '神奧丁': 1,
#          'Bob Mugabe Plays': 1,
#          'DotQ': 1,
#          'Foehn': 1,
#          'Theta': 4,
#          'WHITE RANGER': 2,
#          'cca|Selecta': 1,
#          'panthrex222': 1,
#          'uwu': 1,
#          '???????@???': 1,
#          'Mr.Moo': 2,
#          'italiansp86': 2,
#          '???? ??????? ???a': 1,
#          '@SAYONARA.PERUVIAN': 1,
#          'Audible Chocolate': 11,
#          'C9 S A D B O Y': 1,
#          'T Y P H O O N': 5,
#          'Captain Simian': 1,
#          'DoomBringer': 1,
#          'Hydrocarbon': 2,
#          'KidDad': 1,
#          'ssk': 4,
#          'シンソ': 1,
#          "<font face='ravie'>angeR": 1,
#          'S9': 1,
#          'THE HULK': 1,
#          'Yolo the Swagger': 2,
#          'Похотливый папаш': 1,
#          '---|°Careful°|---': 1,
#          '@[C]risT3am': 2,
#          'Duendi': 1,
#          'No pyro No party': 1,
#          'TtRed': 2,
#          'CxopaLaggeR': 2,
#          'Hassan': 1,
#          'Slad3': 3,
#          'TI': 3,
#          'Tushkanio': 2,
#          'all41-mongol': 1,
#          'Alejandro': 6,
#          'El_Castigador': 1,
#          'LieutenantRoastABotch': 1,
#          'Lol': 4,
#          "Smokin' Joe": 1,
#          '[NEXUS] CH@NgO :P': 1,
#          'AceDoWn': 1,
#          'Never': 4,
#          'Wave': 3,
#          'mrTeroblaze': 1,
#          'quikidon': 2,
#          'Gnev': 1,
#          'HuxFlux': 1,
#          'OranGutan (VAFA²)': 2,
#          'sq`': 2,
#          'z[iNC]': 1,
#          'ку ку': 2,
#          'Bo.Oster': 1,
#          'Grave Digger': 3,
#          'perish the ppl who cant english': 1,
#          'whooooooooooops': 1,
#          'wzz-': 1,
#          'E=mc²=∞²*c=∞': 1,
#          'IneedYourHelp': 1,
#          'Jerassis': 2,
#          'Name.loss': 3,
#          'Ohnoo': 1,
#          'Spiro Fakiro': 1,
#          'skom': 1,
#          'Мужик с руками и �': 1,
#          '?????? ????': 4,
#          '??????? ????': 3,
#          'OutSide': 2,
#          'SlayIce': 2,
#          'VoDHuK': 1,
#          'mafaka': 1,
#          'Random guy': 2,
#          'Saitama': 113,
#          'Six Senpai': 1,
#          'Tenshi': 5,
#          "You're Gonna Have a Bad Time": 2,
#          '^@_(*&%$!~': 1,
#          'dave☻': 5,
#          'DOG DOG DOG DOG': 1,
#          'Empyrean Zephyr.HKG': 1,
#          'L_agger eu': 2,
#          'Ock Ohem Ocktei Wies Barsoom': 1,
#          'Pinoy^^': 2,
#          'Zhooy_': 1,
#          '_yo_yo_': 1,
#          'anjing': 5,
#          '+25': 22,
#          'Gió': 1,
#          'HA.Asura': 2,
#          'I REKT HER NICELY': 1,
#          'Urara Shiraishi': 2,
#          'ren?': 2,
#          'ta-daa!': 1,
#          '『3』s✪': 2,
#          '5K': 2,
#          'FoX': 3,
#          'Luxury': 3,
#          "Mal'chik molodoy": 2,
#          'The Lost': 2,
#          'pes okuliarnatý': 1,
#          'sert1us': 1,
#          'Fiddler': 15,
#          'Trotto': 1,
#          'Victor Cabecinha': 1,
#          'Yahoo': 2,
#          'koteist': 1,
#          'pumping': 1,
#          'rr': 2,
#          'zdasa': 4,
#          'Karl': 11,
#          'Killerpanda': 6,
#          'Lengus': 1,
#          'Lollk0™': 1,
#          'Xerxis@drunken-sylla': 1,
#          'juzeppe': 2,
#          '<font face="Segoe Script">kenDa': 1,
#          'Fz(/++!)': 1,
#          'GRScrew.SeaR': 1,
#          'HeavenCZ': 5,
#          'aspudouf': 2,
#          'q': 2,
#          '难以启齿的柔弱': 1,
#          'Darklune': 2,
#          'Ken  ⁄(⁄ ⁄·⁄ω⁄·⁄': 1,
#          'Light': 20,
#          'SophiaAnne': 1,
#          'Zero.Kao§': 1,
#          'Dekey': 2,
#          'TAB': 2,
#          'carry please ty': 18,
#          'spy': 6,
#          'Grimes': 1,
#          'Ironmonkey': 2,
#          'JayZZZ': 1,
#          '???????? ???????': 3,
#          'Bli5teR': 1,
#          'Ho Hey': 1,
#          'KvargmeisteR^': 5,
#          'Loco': 3,
#          'Shigure': 6,
#          'TESVA': 1,
#          'K1NG': 1,
#          'fabsN': 1,
#          't.R | Rockstar': 3,
#          '2k mmr HERE I COME': 1,
#          'BTFL': 2,
#          'Crimson Lotus': 1,
#          'IIIIIIIIIIIIIIIIIIIIIIIIIIIIIII': 5,
#          'KMC по Dota 2': 2,
#          'OS_Maestro': 1,
#          'bumblebee': 2,
#          'Кот Матроскин': 1,
#          'Bizon': 1,
#          'Goldbrain': 1,
#          'Inori Yuzuriha': 6,
#          'Maggz': 1,
#          'Petros557': 1,
#          'Road To 0K': 1,
#          'Sladoled': 1,
#          '♣eƒect.♣': 1,
#          'AMypkA': 1,
#          'Doni': 4,
#          'GenBi': 1,
#          'JOLO MEMBRANO': 1,
#          'Kapacb': 1,
#          'Masteraven': 1,
#          '____STi____': 2,
#          'croyxez': 1,
#          'Раненая пизда': 1,
#          'Kj`': 5,
#          'Sinapra': 1,
#          'Vorte`x': 3,
#          '[L]': 9,
#          'FishKiLL': 1,
#          'Flin': 1,
#          'Jean Lannes': 1,
#          'helt värdelös': 2,
#          '坑B一抓抓一把': 1,
#          'AfroSamourAie': 2,
#          'Bado.#vr46': 3,
#          'Goldensands': 1,
#          'Void': 4,
#          '???': 73,
#          'Banana': 17,
#          'CAS': 4,
#          'ZnToYk': 2,
#          'dot dot dot': 1,
#          'show me madness': 1,
#          'I Bought [A] Watch Last Year': 2,
#          'Newguy12354': 1,
#          'NinJa': 5,
#          'Nomed': 1,
#          'Pocket Invoker Time': 2,
#          'Tig': 1,
#          'Zack Returns[AD]': 1,
#          '今天吃谁好呢~♥': 1,
#          'IceFlash': 2,
#          'Sad-Clown-Rosario': 1,
#          'Stalx_ftw': 1,
#          'Style': 14,
#          'Gibson_Love': 1,
#          'PEANUT BUTTER JELLY TIME': 2,
#          'VeNoM': 6,
#          '[ZTM].Carlos': 1,
#          'bjpenn.com': 2,
#          'Fck Talha': 1,
#          'Just Jack': 1,
#          'Luttinen': 1,
#          'Lyrlia': 1,
#          'NoiD^': 1,
#          'Pobro': 3,
#          'WHIRLPOOLS [RoadInSky]Seeunextt': 1,
#          'Bilguun Bicktivism': 1,
#          'Burning forever,we still in her': 1,
#          'Smygvild': 4,
#          'WimeSTone': 4,
#          'Zzz': 14,
#          'Admiral [A]lucard0711': 1,
#          "Anu'vis ~ Inv.Crew [KarlonxO]": 1,
#          'Road 4k :D !': 1,
#          'SWISH': 3,
#          'Shia Labeouf': 4,
#          'Wolfie': 5,
#          '.SuperHero': 2,
#          'KnightPumba': 1,
#          'Legacy': 6,
#          'MID OR DOUBLE MID': 1,
#          '~FrozeN|KinG~': 6,
#          'IU': 8,
#          'JohnConnor': 2,
#          'SpinningBalls': 5,
#          'YaBoyQ': 4,
#          'Yogurt': 6,
#          'cRyo': 4,
#          '☜JERICH✪☞': 2,
#          '?????': 66,
#          '?Myrm': 1,
#          'Becker.BOOM': 3,
#          'Ez': 30,
#          'Hansel': 3,
#          'IchiroYutaka': 2,
#          'Miracle-': 44,
#          'mmr ez': 1,
#          'Best player of my house': 1,
#          'Fruitbox': 1,
#          'KaelRain': 2,
#          '坑逼就别tm随机': 1,
#          '雅诗懒呆': 2,
#          'Coach McGuirk': 1,
#          'Tiny Rick': 10,
#          'You Suck Alan': 9,
#          'gp': 3,
#          'oclaf`': 3,
#          '<font face="impact">Whо?Yaka!': 1,
#          'Daenerys': 1,
#          'Mayer Amschel Rothschild': 4,
#          'SHERLOCK': 4,
#          'Syndrome': 12,
#          'great god': 2,
#          'rakamakafol': 2,
#          'Bugler': 5,
#          'MiZhO': 2,
#          'Stuart': 4,
#          '[D2G]Markoz Dax': 1,
#          'lUsUs.BlAnKeT': 3,
#          'shameless': 7,
#          'DOT[A] 2': 1,
#          'GIN_ACE': 1,
#          'Keep Calm': 8,
#          'NEP I KaRmA': 1,
#          'Ob3k1': 1,
#          'VeX.RassLorD': 1,
#          'Vern Vandamn': 15,
#          '!KingR?!': 2,
#          '4Head': 17,
#          'Bokata': 5,
#          'HEBEP__HA__MOPE': 1,
#          'Lagoona Blaze it': 3,
#          'Little Carl': 4,
#          "M a J o R Z e I t ^_^' ;-}": 1,
#          'Moonbeam': 6,
#          'fucking reborn': 3,
#          'FREAKYS': 1,
#          'Moonbow': 2,
#          "Na`Vi.Bo`Ne'": 2,
#          'Used to be sperm': 1,
#          'Love me dead': 1,
#          'MOTAh': 1,
#          'SOOQA': 2,
#          'StarDust': 3,
#          'faintovski': 1,
#          'kikkomään': 1,
#          'Nolifer': 1,
#          'GALAWANG CEDRICK ♥ ツ': 1,
#          'Hudas Gaming ♥': 1,
#          'Noriel  ツ': 1,
#          '_yo_anjing_yo_': 1,
#          'djrules': 1,
#          'DoubleKill': 1,
#          'Kokosik': 1,
#          'S H O C C K E R': 1,
#          'Skuto': 1,
#          'guffy.HD/4k': 1,
#          'horrors': 1,
#          'FeeLSD': 2,
#          'God/Themis': 4,
#          'Vintarin': 1,
#          'bawarri0r': 1,
#          'krewREGE': 1,
#          'BulgarianRetard': 2,
#          'InfiniTy': 1,
#          'SARDEF': 1,
#          'The Good Guy Omni': 1,
#          'ZooM.-': 1,
#          '\\\\ SkyiMuq //': 1,
#          '5k trash(net(da))': 3,
#          'Ryu': 7,
#          'Sett': 1,
#          'atm': 2,
#          'hydra': 2,
#          'superunknown': 1,
#          'Bunny': 3,
#          'ChiPheo': 1,
#          'DADADA': 2,
#          'Earl Ragnar': 2,
#          'Fuck*': 1,
#          'Lyhn': 1,
#          'Violet-Machine': 1,
#          'fcking trash!': 1,
#          'Demon_nL': 1,
#          'Ega': 1,
#          'I am not a parking garage': 1,
#          'PaFoS': 1,
#          'PsychoO': 3,
#          '[Z]aha': 1,
#          'collapsE': 1,
#          'friendship': 1,
#          'F': 1,
#          'MODNIY': 1,
#          'We are Pain': 4,
#          'trava supamida': 2,
#          'Žčš': 1,
#          '#Kabalzzz': 1,
#          '0980': 6,
#          'Elix': 3,
#          'Ithilien': 1,
#          'Too many retards on CORE heroes': 1,
#          't1gra_R': 1,
#          'top kun': 3,
#          'ニコラス ブラウン': 2,
#          'Hiken no Ace': 1,
#          'Mochi': 2,
#          'littlepandaALLSTARS': 1,
#          'mcjenizaro': 1,
#          'paulinhok14': 1,
#          '『\u3000\u3000』': 14,
#          'CR_ JAM': 1,
#          'Pedophillic Platypus': 3,
#          "SumaiL'": 1,
#          '幻魄': 1,
#          '心系宇宙的肉松饼': 2,
#          'Glenn still alive': 2,
#          'KAREV': 2,
#          'O.o': 13,
#          'Perfection^': 1,
#          'Pk': 2,
#          'The Adventurer - Finn': 2,
#          'Zlynf*': 1,
#          '1x9 [Mute All Chat √]': 1,
#          'KOKIA': 2,
#          'NBrait': 2,
#          'Solo(Win)You': 1,
#          'Str8jaket': 1,
#          'player 777': 1,
#          "ƒr0gÉlt`Let's Get Schwifty": 1,
#          'ϟ CITIZEN ϟ': 1,
#          '2k mmr player': 1,
#          'SALAD FINGERS': 2,
#          'UnOxiA~': 1,
#          '989': 1,
#          'REvo.f': 10,
#          'canceL^^': 7,
#          'VALKYRIA': 1,
#          'kokO': 1,
#          '{THC}┌∩┐( -_- )┌∩┐': 1,
#          'Pirarucu': 1,
#          'Pixxt': 1,
#          'ScSd': 4,
#          'UFO': 5,
#          'su1/2': 5,
#          'thirteen': 1,
#          'Metabug': 2,
#          'homer': 1,
#          'Clothespeg': 3,
#          'LASERCAT JM-': 1,
#          'Mo': 7,
#          'Rohkin': 1,
#          'The Boy': 18,
#          'Verlauste Bergziege': 9,
#          'Doro': 18,
#          'KauppaneuvosFiti': 10,
#          'LexXx': 1,
#          'Lurgo': 13,
#          'i cri evry tiem': 2,
#          'AC↯DC': 2,
#          'Baggy Kunt Flaps': 1,
#          'KillingForYou': 1,
#          'Kunja': 1,
#          'Leijona': 2,
#          'TheKevkov | csgohub.gg': 1,
#          'igreedisgood': 1,
#          'Infinity': 7,
#          'MASHA ROSTOVA': 6,
#          'Ralfrs': 7,
#          'TDk.Mael!': 1,
#          'plejahh    #HARD': 1,
#          'ADi': 4,
#          'Flop': 3,
#          'FromParadiseToHell': 1,
#          'Jesus': 23,
#          'Kumi': 3,
#          'MyKnock': 3,
#          'Statick': 10,
#          'fLiNe': 1,
#          'Agent A.': 1,
#          'BaconOnFire': 1,
#          'MCSignõrinem': 8,
#          'Player Michi!': 1,
#          'SGT Pepper': 1,
#          'The_Architect': 1,
#          'WOOOOOOOOOOOOOOOOOOOOOO': 1,
#          '@JxDota': 4,
#          'A D R E S T I A': 1,
#          'Aurora': 4,
#          'Blitzerine #low pool': 1,
#          'LADLAD NA JOM GANG': 1,
#          'LucyHeartfilia.': 2,
#          'fk my team.mid or afk': 1,
#          '海盜王': 1,
#          'Digital Dash': 6,
#          'Lysergide': 1,
#          'Mr.Sandman': 2,
#          'Sodomy': 1,
#          'Wolfthorn': 3,
#          'EzziHell': 1,
#          'ResoLuT1oN': 2,
#          'Untoquedeinspiracion.': 1,
#          '[Sir./#0$U€]': 1,
#          'oogie': 1,
#          'L=ky² (LOSER)': 2,
#          'Pimp™': 4,
#          'Rick': 35,
#          'TZKali.Pornhub #rekt': 1,
#          'Mr Bulldops': 1,
#          'Poshisonte': 1,
#          'Red Panda': 8,
#          'RyanMC': 1,
#          'SEIFER': 1,
#          'Shoeless Joe': 1,
#          'T A O': 2,
#          'Verde^': 2,
#          'kipper': 1,
#          '-xXlllToNylllXx-': 3,
#          'Chester204': 1,
#          'Give Away..!!': 1,
#          "I'll Show You": 8,
#          'Kingperu': 6,
#          'Nyvo': 1,
#          'Y [.] L [.]': 4,
#          'dp.Fitzz': 4,
#          'watt': 4,
#          'AIZEN.uuuuu9': 2,
#          'ASUS': 2,
#          'Bob': 30,
#          'KnowThyProNyorkx': 2,
#          'MID LANE SLAYER': 1,
#          'VII-XXIX-MCMXCII': 2,
#          'needle_boy': 1,
#          'ＺｈｙＫｉｎ': 1,
#          'Alicia': 1,
#          'Boob Guy': 1,
#          'Dajđa.Ba': 1,
#          'ThaI^13': 4,
#          'Tom Ganks': 18,
#          '-TnX.Skold': 2,
#          'KILLING IN THE NAME': 9,
#          'Konoyarō': 1,
#          'Pure_zeus': 2,
#          'Simple«<3C': 2,
#          'Sky_TriploKiL': 2,
#          '@kaitoDOTA': 1,
#          'Aragoat': 3,
#          'Double [T]': 4,
#          'Fuccboi': 1,
#          'GIVEN UP!': 1,
#          'VatOmONNN is back │◙--◙�': 1,
#          'threeric': 4,
#          'Kaleep': 1,
#          'KillerTrax': 1,
#          'Pabst': 1,
#          'Securitron Mk II': 1,
#          'Shaka de Virgo': 1,
#          'c::::[]::::::::::>': 1,
#          'chulo Beaver': 2,
#          'Drizzzy Drow': 1,
#          'Koonta.': 3,
#          'Vinegar Strokes': 2,
#          'z77x': 1,
#          'Boss': 20,
#          'Xion': 8,
#          'burlow': 2,
#          'ysath': 1,
#          'zanjin': 3,
#          'BossNiggas': 1,
#          'FeedDaddyBigFail': 1,
#          'Mongols !': 1,
#          'Morals': 3,
#          'SHLURP': 1,
#          'Flower': 11,
#          'Funkknight': 6,
#          "THEY SEE ME ROLLIN'": 1,
#          'jep': 4,
#          '<font face="Segoe Script">david': 1,
#          'Nero': 18,
#          'crunchy': 1,
#          '¥ Kamael ¥': 1,
#          'Eraj': 7,
#          'I KIM TAEYEON': 1,
#          'Louis Litt': 10,
#          'redbull demon': 2,
#          'BoostMMR 5k': 1,
#          'Cyrex': 2,
#          'Free-Look': 1,
#          "JR''DIzON": 1,
#          'Magnus (ViC)': 1,
#          'Standin.OnTheChair': 1,
#          'xitler': 3,
#          '3astWood': 7,
#          'Lagmaster': 6,
#          'Mistress 9': 8,
#          'Noobility': 1,
#          'Sn0_Man': 13,
#          '<font face="Magneto">Requiem': 1,
#          'Beastmode Joyth': 1,
#          'Peanut Bristle': 3,
#          'T125': 4,
#          'Yolo Swagginz': 1,
#          'nz*killa': 1,
#          'pounce v 4500': 1,
#          'raku000': 1,
#          'Corvus': 3,
#          'Halestorm': 4,
#          'Kyb': 2,
#          'Lord Garbington': 1,
#          'No.HDVD': 1,
#          'Stun now!': 1,
#          'Videojamm': 3,
#          "What's Poppin'": 17,
#          '0_0;,RON_;o0': 1,
#          'AkatZuKi': 3,
#          'HoMo-Central....': 1,
#          'Jumbo': 6,
#          'Player': 24,
#          'Soy La Leche': 3,
#          'XPM': 1,
#          'Eagle': 40,
#          'Jarin Sky': 3,
#          'M.C.': 6,
#          'crom': 8,
#          'dionysus': 4,
#          'iAnnihilate': 5,
#          'just a boy': 4,
#          'miasma': 3,
#          '@xPro ッ': 2,
#          'C@rboN_Zp': 1,
#          'Maloy_12': 2,
#          'The Feel Good Drag': 1,
#          'TimeVig': 1,
#          'Личный номер 69': 1,
#          'анат кунэм !!!111': 1,
#          'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA': 5,
#          'CaseyJones': 9,
#          'Scrubs': 1,
#          'ineedtostartover': 1,
#          'yhp': 1,
#          'ㅇㅇㅇ': 1,
#          'Mirror°': 1,
#          '意sama': 1,
#          'Dr. Krieger': 1,
#          'Falcon': 10,
#          'bojangles': 1,
#          'hotsauce': 1,
#          'Ayahuasca': 1,
#          'Caped Baldy': 14,
#          'K - OZ': 1,
#          'Kim!': 1,
#          'Looky': 1,
#          'Tabotchok!♥': 1,
#          'XIII': 16,
#          '^_^': 29,
#          'iNFRA': 1,
#          'koozy': 4,
#          '<font face="Segoe Script">:)': 1,
#          'DESTHROYER': 1,
#          'DeathxSeraph': 1,
#          'SwiindLe (:': 2,
#          'VEe': 1,
#          'Victorious-': 1,
#          'X-FiVEhunter': 1,
#          '[MNI]HOODINI': 1,
#          'sheng22¯\\_(ツ)_/¯': 1,
#          'Funkadelic Jive Turkey': 4,
#          'Trex': 2,
#          '088': 1,
#          'Diavil': 4,
#          'Flushing': 1,
#          'HyperX.No mercy': 1,
#          'M-art.Sk0t': 1,
#          'thbt >:E': 7,
#          'Geto': 1,
#          'Konomo': 1,
#          'Paradox-|X': 1,
#          'PasKudA': 1,
#          'S.H.K <3': 3,
#          'Sven': 6,
#          'raging fury': 1,
#          'Основной': 1,
#          'ПилОт': 1,
#          '21-kilogram Pike': 1,
#          'D': 19,
#          'DrooonThug': 2,
#          'LivingLeaves': 1,
#          'Mesut Özil': 2,
#          'Santa Claus': 1,
#          'sAer': 4,
#          'Marvin': 3,
#          'cHriS™': 2,
#          'u4': 1,
#          'ТОЛСТЫЙ НА ТРОНЕ': 2,
#          '! ! ! ! !': 1,
#          'Balamut_': 1,
#          'Captain Adorable': 10,
#          'Dark Ghost ™': 1,
#          'DarknesS': 1,
#          'Flint': 3,
#          'ToyStory': 1,
#          'bembo': 2,
#          '✪ Лысый из Бразе�': 1,
#          'PINK': 1,
#          'Xiaoting Pan': 1,
#          'arai waaaaa': 1,
#          'Ghost_Khan.Rape': 1,
#          '>The-B.boy<': 3,
#          'Feniks': 4,
#          'GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG': 3,
#          'MaNiA': 3,
#          'NekoStyle': 1,
#          'Sissel': 4,
#          'Standin.xGod!': 1,
#          'gamefreak111': 1,
#          'sA 24:* goooo 5k ez': 2,
#          'Canfly': 1,
#          'KRYST4L': 5,
#          'Narkos': 1,
#          'Oykek': 4,
#          'Puck You': 3,
#          'What So Not': 1,
#          'When crumbling': 1,
#          'Zaraki': 1,
#          'Ebaken': 1,
#          'KiMME': 1,
#          'METANUEHUWEGCV': 1,
#          'Zamiel': 1,
#          '[ RUS 60 ] Dmas': 1,
#          'mInI': 1,
#          'Шмальгаузен': 1,
#          '=)': 19,
#          'El Jefe': 1,
#          'LoL-ZzZ': 1,
#          'RK': 4,
#          'michas': 3,
#          'xioxi (>●.●)>': 2,
#          'üzer': 3,
#          ':grave:': 1,
#          'FFY~430~': 1,
#          'Shiykaa<3': 1,
#          'illegal Parking': 1,
#          'KITTY HAS TO GO': 15,
#          'MMR=Meet More Russians': 1,
#          'OG.Miracle-': 8,
#          'Tractør': 5,
#          'dzubej_kibagami': 1,
#          '● Turboooooooo ●': 1,
#          'ElMammoth': 4,
#          'Losing Streak.. FTW': 1,
#          'Pourosis': 12,
#          'Splashツ': 1,
#          'USSGuam': 4,
#          '†.回來的是真實的.†': 1,
#          '????': 75,
#          'BinhRampage': 1,
#          'Bo BO': 1,
#          'FuckingNoobThenTalkLikeShit': 2,
#          'SoonSoon': 2,
#          'TeenY-Tatum': 1,
#          '[MY]CapSicK-Cum': 2,
#          'memberoftesla': 1,
#          'Ace': 38,
#          'Ascernu': 1,
#          'Bruno17': 1,
#          'ErDj': 1,
#          'NIGHTEAL': 1,
#          'SHA-BANG': 2,
#          'SŧasanĄ': 1,
#          'Sha Ft. TwoZero': 1,
#          'Stupendous': 1,
#          'Tony Stark': 4,
#          'zzZ': 2,
#          '@Kloud #HeForShe 我会一直�': 1,
#          'Bleezieeeee': 5,
#          'Divine Law': 4,
#          'Nate Higgers': 11,
#          'New Idol': 4,
#          'Rusy': 4,
#          'The Last One': 4,
#          'confessor': 13,
#          'farm magician': 1,
#          'Spontaneity': 1,
#          'grillz': 12,
#          'kj': 1,
#          'ride the icening': 1,
#          ...})

# %% [markdown]
# #### Players and the number of matches they played

# %%
count_by_id = pd.DataFrame.from_dict(id_count, orient = 'index', columns = ['count']).reset_index()
count_by_id
# Out:
#                         index  count
# 0                   6k Slayer      1
# 1                    Double T      2
# 2                        Kira     25
# 3                      Monkey     12
# 4                    Trash!!!      1
# ...                       ...    ...
# 177985                kabutee      1
# 177986          DamN.Pussy_Jr      1
# 177987         DamN.Sakura_Jr      1
# 177988              PINAGPALA      1
# 177989  WorstDayOfMyLife^Ever      1
#
# [177990 rows x 2 columns]

# %% [markdown]
# #### Players who played more than 10 matches

# %%
freq_user_df = count_by_id.loc[count_by_id['count'] > 10]
freq_user_df
# Out:
#                           index  count
# 2                          Kira     25
# 3                        Monkey     12
# 13                    Anonymous     30
# 24                         Matt     21
# 45                 melissachan♥     11
# ...                         ...    ...
# 130782                 MinDFirE     14
# 131143                  Alright     11
# 132391                FraNigiri     12
# 135655  [V].Trying to walk away     11
# 136991              Marble Soda     11
#
# [1807 rows x 2 columns]

# %%
freq_user_id = freq_user_df['index'].tolist()
freq_user_id
# Out:
# ['Kira',
#  'Monkey',
#  'Anonymous',
#  'Matt',
#  'melissachan♥',
#  'Kenny',
#  'Doug Carl',
#  'KingJonesGaming',
#  'Max Tryhard',
#  'bourgeoisie',
#  'Joe',
#  'Hades',
#  'ебать',
#  'Mithrandir',
#  'AA',
#  'Bruce Wayne',
#  '†',
#  'Kai',
#  'shibui',
#  'Maiku Mori',
#  'ALWAYSWANNADIE',
#  'GGWP',
#  'BrianCooper1',
#  'Kappa',
#  'Bob Ross',
#  'Audible Chocolate',
#  'Saitama',
#  '+25',
#  'Fiddler',
#  'Karl',
#  'Light',
#  'carry please ty',
#  '???',
#  'Banana',
#  'Style',
#  'Zzz',
#  '?????',
#  'Ez',
#  'Miracle-',
#  'Syndrome',
#  'Vern Vandamn',
#  '4Head',
#  '『\u3000\u3000』',
#  'O.o',
#  'The Boy',
#  'Doro',
#  'Lurgo',
#  'Jesus',
#  'Rick',
#  'Bob',
#  'Tom Ganks',
#  'Boss',
#  'Flower',
#  'Nero',
#  'Sn0_Man',
#  "What's Poppin'",
#  'Player',
#  'Eagle',
#  'Caped Baldy',
#  'XIII',
#  '^_^',
#  'D',
#  '=)',
#  'KITTY HAS TO GO',
#  'Pourosis',
#  '????',
#  'Ace',
#  'Nate Higgers',
#  'confessor',
#  'grillz',
#  '._.',
#  'feeder',
#  'Axosh',
#  '<><',
#  'snoopRat',
#  '< blank >',
#  '-.-',
#  'Hey b0ss',
#  ':D',
#  'John Cena',
#  'Zero',
#  '123',
#  'art',
#  'MinMorts',
#  'Skodak',
#  'Fred',
#  'Lumos',
#  'Marik',
#  'sad',
#  'O_O',
#  'Xin',
#  'Jason',
#  'The Joy of Feeding',
#  'echowon',
#  'Smile',
#  'IamThor',
#  'Weed',
#  'Hello',
#  'Jake',
#  'ThaddeusV',
#  'SimpLe',
#  'Vynil | Zyn',
#  'Fluffy',
#  'Horse',
#  'Requiem',
#  '111',
#  'DragRiver2',
#  'Hodor',
#  'KappaRoss',
#  'NotLikeThis',
#  'Michael',
#  'Banyu',
#  'Ellimist',
#  'Casto',
#  'Bacon',
#  'hehe',
#  'soy papá',
#  'Pineapple KAMIKAZE',
#  'Joker',
#  'Insert',
#  'Jiten',
#  'Grumpy Green',
#  'Still ШṙȧϮЋ #PateHinoys',
#  'Arbi',
#  'Chill',
#  'Psycho',
#  '`Blurry Eyes',
#  'Cotton.Karma',
#  'Ri',
#  'G_G',
#  'yolowarrior',
#  'Goku',
#  'trashcan',
#  '14',
#  'Carl',
#  'ALWAYSWANNAFEED',
#  'eunhwa',
#  'Baldur',
#  'OMG! U still believe in LOVE???',
#  'James',
#  'Mayhem',
#  'Tensai >.<',
#  'Meow',
#  'qwerty',
#  'Malicious Clay Pigeon',
#  'Defensif^',
#  'Hachiko',
#  "Fantini's Fantasy",
#  'NAES',
#  'One Punch!',
#  'corn',
#  'Nigga',
#  'TED',
#  'Number Juan Doto Player',
#  'Terpcasl',
#  'JoeBlender',
#  'Chaos',
#  'zzzzzzzzz',
#  'PUNX',
#  '.inf',
#  'Goofy Hell',
#  'KMZWAY87AA',
#  'Bloop',
#  'Iriemember',
#  'AIR-EH-BUS',
#  'Jeff',
#  'Vishnup_',
#  'The Dude',
#  'nice la',
#  'FredJ',
#  'Loki57',
#  'Nuker',
#  'Reaper',
#  'Stallon',
#  'TINKLES',
#  'kadal_kutub',
#  '猫NekO!',
#  'Yoshi',
#  'jd',
#  'santos',
#  'BiG BaNaNna !',
#  '@hiro',
#  'Snipe Desu~',
#  'Skiller',
#  'Angry Nikolai',
#  'El Dude',
#  'Leo',
#  '@KossDota',
#  'Ephemeral',
#  'Buster',
#  'tehdilgerer',
#  'Ｂ Ｅ Ｎ Ｎ',
#  'hG.IntrinsiC',
#  'D4D.EldestDad.420',
#  'Rorschach',
#  'recovery',
#  'Thomas The Dank Engine',
#  'Keyser Soze',
#  '#ano.Ainsley Kek',
#  'Dictionaries',
#  'Monster',
#  'Soffish',
#  'CHI LONG QUA',
#  'Ho랑이',
#  'XXX',
#  'Apple',
#  'The Seven Deadly Sins',
#  'Shiroe',
#  'rust',
#  'turn right',
#  'D.',
#  'SENPAI',
#  'Myth',
#  'X',
#  'Arts',
#  'Chippy',
#  'Deemi',
#  'CaptainCrespo',
#  'Skayl',
#  'ducffxiv',
#  'NB',
#  'TinkerBell',
#  'Dennou coil',
#  'Atlas',
#  'Deodorant spray',
#  '<blank>',
#  'Vendetta',
#  'Frank',
#  'Urist',
#  'Deez_Nuts',
#  'September',
#  '1738',
#  'pyrofrantic',
#  'kellyMONKEYS',
#  'Shadow',
#  'The Wanderer',
#  '...',
#  'Hyy',
#  'Lặng Lẽ Tổn Thương',
#  'Sleeping_[D]og',
#  'bwew',
#  'Rawdog',
#  'Wakalulu',
#  'paloralogram',
#  'TB.Thành Lê',
#  'Solaris',
#  'A Wild Smurf',
#  'Memories',
#  'Spooderman',
#  'Sloth',
#  'G.',
#  'KING',
#  'Kevin',
#  'Ori',
#  'Mirakuru',
#  'YOLO',
#  'DK',
#  'Lelouch',
#  'scrub',
#  'Monkey D. Luffy',
#  'Mr. Meeseeks',
#  'Road to 4k',
#  'Rigby',
#  'Lost_Faith',
#  'Light of Darkness',
#  'BestMidPlayer',
#  '22',
#  'happy little clouds',
#  'Chrom',
#  'P3G || FreexIIV',
#  '.....',
#  'Fartsparkles',
#  'TZA Da God',
#  'TBD',
#  'Dream',
#  'haha',
#  'Dog',
#  'Prince of Excrement',
#  'VdoubleI',
#  'FOX',
#  'a winner',
#  'Akashi Seijuro',
#  'Voire Dire',
#  'MID',
#  'Road to Al-Qaeda',
#  'GG',
#  'leasey^',
#  'L.A. Beast',
#  'MID OR FEED',
#  'ice',
#  'Ahov',
#  'West Street Variety',
#  'LOVE-is-EZ but I hate you',
#  'Harry',
#  'devilonearth666',
#  'modjas',
#  'Spazzkid',
#  'Buzenbazen',
#  '321',
#  '|||||||||||||||||||||||||||||||',
#  'Scrotes',
#  'Shade',
#  '????????',
#  'sojtucker',
#  'Zaine',
#  '..',
#  'Lepo Lepo',
#  'Smegma',
#  'WADE !!',
#  '[A]',
#  'RED',
#  'King Meme The Meme King',
#  'boo',
#  'scantid',
#  'vaft',
#  'VALAR MORGHULIS',
#  'AirmailMRCOOL',
#  'this is the life that i chose',
#  'FeelsBadMan',
#  'Jack Sparrow',
#  'Lets get this underway',
#  'barelyrobot',
#  'Dendi',
#  'A',
#  'Cobalt 60',
#  'Hatsune Miku',
#  'lkgjhdsijofhgdiug',
#  'Cock Goblin',
#  'ABC',
#  'JOHN CENA',
#  'mURSAful',
#  '-25',
#  'Ronny',
#  'ivenbetter',
#  'MettGyver',
#  'XD',
#  'xx',
#  'Brownballa55',
#  '"nGy"',
#  'Nexr',
#  'βeardong',
#  'ihatewieland',
#  '.',
#  'Rizwanovich',
#  'SNAAAAKE',
#  'chopstixZ',
#  'Dante',
#  '0.0',
#  'J.',
#  'Nijbu',
#  '1017',
#  'Justice',
#  'Sentinel',
#  'Han Solo',
#  'JM',
#  '攀登',
#  'aTly',
#  'StarScream -',
#  'KN.4ever.♥™®',
#  'JJ',
#  'K',
#  'Zero97M',
#  'Loki',
#  'Cringer',
#  'Yung Lean',
#  'Rage',
#  'A0',
#  '소녀시대-김태연',
#  'bad',
#  'ZeTo',
#  'La Spada',
#  'Dr.X',
#  'w33',
#  'Spla$H',
#  'MingLee',
#  'Tom',
#  'Ice',
#  'XuT',
#  'Narcotix',
#  'Emperor',
#  'Escherichia Coli',
#  'Ginko ギンコ',
#  'Ceyler',
#  'B-Rabbit',
#  'TeaPirate',
#  'Lucifer',
#  'Morrow ᕕ',
#  'jaynanners',
#  'Carlos',
#  'Vincent',
#  'Aeon',
#  'Panda',
#  'zero',
#  'キャプテン大きなペニ',
#  ':)',
#  'Λ',
#  '456',
#  '...............................',
#  'M',
#  'Jon',
#  'Fatality',
#  'Luke',
#  'Shadow Pain',
#  'Hunter',
#  'Fiendish Dr Wu',
#  'Pika',
#  'Salem',
#  'MeerCat',
#  'Snow',
#  'Mark',
#  'unlucky',
#  'ONiGiRi',
#  'Batman',
#  'Flash',
#  '(have fun, pal)',
#  'Heisenberg',
#  'Harvey "Harvey" Harvey',
#  'Enucatl',
#  'Kain',
#  'Marymar♥',
#  'Maestro',
#  'Smitty Werben ¯\\_(ツ)_/¯',
#  'Onions123',
#  'Morty',
#  'LOL',
#  'Z',
#  'Faronel',
#  'Byte',
#  'Yuki',
#  'whatever',
#  'qwe',
#  "'Ywp",
#  'Captain America',
#  'Law',
#  'Thanatael',
#  'cocodino',
#  '♥',
#  'MattTheAvaricious',
#  '[STR].MissBug',
#  'Potato',
#  'R',
#  'Logic',
#  'Alex',
#  'iPeon_GM',
#  'Solo',
#  'JAFAR',
#  'S',
#  '[     ]',
#  "You can't run from heaven!! Bro",
#  'noob',
#  'Kaboom',
#  'dream is ded',
#  "[EE's Disciple]",
#  'Tømmermannen',
#  'ツ',
#  'B',
#  'w/e',
#  'SAMKOOOOOOOOO',
#  'Wok',
#  'asdf',
#  'bneutrality',
#  'xD',
#  'Tick Tock',
#  'Unknown',
#  'Bravo VietCong',
#  '400 Lux',
#  'Uldred',
#  'BigBear',
#  'Illi',
#  '9/10',
#  'Phenomenal',
#  'Moose',
#  'Ghost',
#  'Robin',
#  '322',
#  'Hope',
#  'mäniaK ʶ',
#  'Viridian',
#  'Black',
#  'APICLEL.Seppiee',
#  'BANZAI',
#  'Thrower',
#  'asd',
#  '1',
#  '?',
#  'QQ',
#  'Pablo Escobar',
#  'Alucard',
#  'Chief',
#  'MaX.OmEgA`',
#  'Gary',
#  '[DeadWithPain]',
#  'Charlie',
#  'Vanilla Bear',
#  'Baxter',
#  'Madara',
#  'Döner',
#  'mylo',
#  'Josh',
#  'Noob',
#  '[GeTMS]',
#  'printf("%c",retard);',
#  'TheLast',
#  '1234',
#  'sky.',
#  'haat.by',
#  'Redemption',
#  'Taylor Swift',
#  'ベル마Jemo-왕ゼブブ',
#  'OMG',
#  'qq',
#  'eRzR_',
#  'Naylor',
#  'Welcome to random boyz',
#  'SY',
#  'enenlove ツ',
#  'kappa',
#  'Ya',
#  'Medivh',
#  'PANDA',
#  'Dondo',
#  'qweqwe',
#  'King',
#  'unstoppable',
#  'Valar Morghulis',
#  'Jerry',
#  'Mitsu',
#  'HelenaLive',
#  'Hiruma',
#  'bob',
#  'Diskover',
#  'Fire',
#  'Pablo',
#  'Pikachu',
#  'Uchiha Madara',
#  'Daemonum Tert',
#  'Mottley',
#  'CHEWIE CHEWBACCA',
#  'rKaiser',
#  'Glen',
#  'Link',
#  'Hype!',
#  'Gilgamesh',
#  'Agressif',
#  'Svarog',
#  'Ragnar Lothbrok',
#  'BOSS',
#  'SchuhShine',
#  'JC',
#  'Red',
#  'little baobao',
#  'Death',
#  'H.D.C. Oti',
#  'Andy',
#  'Bob™',
#  'Daefron',
#  'Terrorblade',
#  'Azrael',
#  'Flame',
#  'Jet',
#  'Brotherman Bill',
#  'Roland',
#  'PENOPT.вa†ѕυ ¦>',
#  'WHAT?!',
#  'jingspir[A]l',
#  'DTN',
#  'lol',
#  'road to zero mmr',
#  'trollfederer',
#  'NKR',
#  'Gucci MagiK',
#  'Myrmidon',
#  'yolo',
#  'Miracle',
#  '-',
#  'AtField.Barba',
#  'BikerBoY',
#  'Rin',
#  'Slayer',
#  'Urgel',
#  'MRX',
#  'Darl2en',
#  'SAITAMA',
#  'Oxizakre',
#  'Iditor',
#  '@ChmieluDota',
#  'Chris',
#  'WaaDaaFaak!?',
#  'Dragnipur',
#  'Great Deku Tree',
#  'Hans Moleman',
#  'Strider',
#  'RS',
#  '5to7',
#  'KutTaoLang',
#  'kk',
#  'JohnDoe',
#  'Sorry',
#  'Internet Explorer',
#  'zzz',
#  'Hansi',
#  'KappaPride',
#  'cobaca maosa',
#  'BRACUBI',
#  'Brian',
#  'sSam',
#  'RL',
#  'Neo',
#  'Sweet TittyMo',
#  '??????????',
#  'kRAnk-.-',
#  'XO',
#  'twitch.tv/pesdota #Hope',
#  'The Only God',
#  'Sir Pudgealot',
#  'ybwprod',
#  'Hans Humpty',
#  '<3',
#  'Darkness',
#  '?????????',
#  'Vince',
#  'GeGe',
#  'xd',
#  'ok',
#  'Shady',
#  '<Font face="Arial">Bardock',
#  'montezuma',
#  'Vroksnak',
#  'Tony',
#  'Ares',
#  'Totti#Smauking dat Seaweed',
#  'Flóki',
#  '[DoGe]Lopaha',
#  'SSF',
#  'DoctorVox',
#  'Error',
#  'Fury',
#  'JR',
#  'Tahurtz',
#  'Faith',
#  '420 booty wizard',
#  'Emil',
#  'Ferdinand Magellan rekt sejarah',
#  'Drak0n',
#  'Muffinator',
#  'Max',
#  'Сын Собаки',
#  'Flow',
#  "Blacque The Lil' Rooster",
#  'RANDOM OR RIOT',
#  'Mr. Bay',
#  'Hurenbär',
#  '@builder_247',
#  'ThaDrone',
#  'Animagne',
#  'G',
#  'Thejoyofdota FeelsBadMan',
#  'Ragnar',
#  "Ehh!! What's up doc?",
#  'Kronenboy',
#  'Nando',
#  'bonjour pizdec',
#  'Silent',
#  'Dontores`',
#  'Flawless',
#  'Deadpool',
#  'Thor',
#  'matassos',
#  'Isoboy',
#  'Pд††дЯ',
#  'Jack',
#  'IHuINTeIR',
#  'Baba Yaga',
#  'Seatech',
#  'Ricky Spanish',
#  'Cronos',
#  'Elvis',
#  'Frozen',
#  '✿ sk_Baymax™♠',
#  'Sean',
#  'Fayher',
#  'Hero',
#  'brodericoh',
#  'David',
#  'Leon',
#  '「Kushi」',
#  'Thunderdyne',
#  'No more heroes',
#  'HolyMoly -QsQ-',
#  'One Punch Man',
#  'Sindor',
#  'Kirito',
#  'Mortal Vengeance',
#  'Shanks',
#  'Milk',
#  'Arothe. /muted all',
#  'klaytog',
#  'Bahmut',
#  '??????',
#  'Captain',
#  'S A D B O Y',
#  'deranzo',
#  'Mikasa',
#  '69',
#  'bloodhound',
#  'rYaiEn',
#  'Spartacus',
#  'Valkyrie',
#  'Fuuzzie',
#  '[DG]Hoppen',
#  'Destroyer',
#  'wizn',
#  'DSwissK',
#  'Donk',
#  'Phoenix',
#  'Fuzz',
#  'b1ngo',
#  'inferior slavic chromosome',
#  'Doge',
#  'Superman',
#  'Envy',
#  'XTN',
#  'Grom',
#  'Coco',
#  '[N]ooble',
#  'HorseFeeder',
#  'Hakuna Matata',
#  'RFA',
#  'dotato',
#  'Perfect Is Shit',
#  'Hi, Can I have mossarella stick',
#  'Madness',
#  'Adlet Mayer',
#  'Huh?',
#  'J_Quincy_Adams',
#  'RyuKen',
#  'Rampage',
#  'Radix',
#  'Valazus',
#  'x-0ne (G.O.D)',
#  'ez',
#  'MïќE LtR',
#  'ausoi',
#  ':3',
#  'MrMkay',
#  'Sara :)',
#  'Proto',
#  'nicenicenice',
#  'Cristyx',
#  'Ѵirtualghost',
#  'Hashirama',
#  'Happy',
#  'TySAD',
#  'atreides',
#  'Do --',
#  'Skiper',
#  '|NeX| Capta1nben',
#  'Petchef',
#  'doN',
#  'iRoge',
#  'fohu',
#  '??',
#  'Clouds',
#  'Interpol',
#  'Hugs from Jewland',
#  'Warrior',
#  'Darbax',
#  'Mighty Manatee',
#  'Fox',
#  'blank',
#  'Benegripe',
#  'BabyRage',
#  'Pineapplefruitdude',
#  'wλrthen',
#  'Pavi',
#  'Yolo',
#  'Bum bum - Bot',
#  'Sugy',
#  'uhuhuh',
#  'emge',
#  'Hippie',
#  'Zolo',
#  'Pyro',
#  'ALBERR G',
#  'beaverknight',
#  'Jon Snow',
#  'Cookie Monster',
#  'peco',
#  'Frankenstein',
#  'CJ',
#  'Alexander den Store',
#  'Rex',
#  'central.e-JAM',
#  'LarryFish',
#  'TheSquid',
#  'Trollypops',
#  'Đưa Nhau Đi Feed',
#  'Zeeks',
#  'Metfly7',
#  '???????',
#  'Moongazer',
#  '.......',
#  'tunes',
#  'Inspector Norse',
#  'ATC',
#  'DarkwaveMD',
#  'Argoniur',
#  'Nova',
#  'Stark',
#  'Lel',
#  'Jim Carry',
#  'Richard',
#  'Ap.Fofole',
#  '33',
#  'YB',
#  'Schmidt',
#  'Schlebben.XD',
#  'ghjklkvfcdfghj',
#  'Smoke',
#  'Cpt. Donatário',
#  'Funk You',
#  'Ximo 1er',
#  'Rain',
#  '直美 Naomi',
#  'BuRN',
#  'xWinkler',
#  'N',
#  'Blue',
#  'G. R. T.',
#  '^^',
#  'DeadShot',
#  'minK',
#  ':(',
#  'Pain',
#  'Jana',
#  'Nyte',
#  'Miley',
#  'Pizza',
#  'Recovery',
#  'Av',
#  'Eimyx',
#  'MaSta',
#  'gorgeous',
#  'Max Guymer',
#  'Flex Luthor',
#  'Windalfr',
#  'Gaius Gannicus',
#  'dbl',
#  'Just Do It!',
#  'Titane',
#  'SamuraiJack',
#  'Svonn',
#  'Boobs-chan',
#  'Moe-Chan',
#  'TSF.theSUNZI#NobodysHome',
#  'Juca',
#  'ThugLife',
#  'YBP',
#  'Lardo',
#  '-_-',
#  'Shinji',
#  'Csanszi',
#  'Starkey',
#  'McLovin',
#  'Aurlon',
#  'Oli the Optimist',
#  'Omega',
#  'Alison',
#  'Big Smoke',
#  '000',
#  'BB',
#  'Penguin',
#  'TzenTzen',
#  'Master',
#  'AzoR725',
#  'Inigo',
#  'Pingouin',
#  'belenkaya',
#  '[$wAg].Zaldian',
#  'Awesome',
#  '༼ つ ◕_◕ ༽つ',
#  'Zimzo',
#  'MoonMoon',
#  '[siQ] DRUNKEN-MASTER',
#  'chrizzl',
#  'VaLoS',
#  'Tryhard',
#  '.Atheris',
#  'Crispy Rog and Chips',
#  'Gdo',
#  'svenskewar',
#  'Rabbit',
#  '....',
#  'Hubcap',
#  'Maybe',
#  'JOHN HITLER',
#  'Lord',
#  'Big Dick Bandit',
#  'Garam',
#  'sick4Robbie',
#  'BurnIt',
#  'Etherus',
#  'Alpha',
#  'Rkg - Xin Player -',
#  'Insidious_Mouse',
#  'Deadly^_^',
#  'He|ìx`',
#  'Koppermouth',
#  'RuSup',
#  'JUKE NUKEM',
#  'Rusted',
#  'pitzuuu',
#  'Big Boss',
#  'Stolicnaya',
#  '石原さとみ',
#  'camd11',
#  'Road to 5k',
#  'rngod',
#  'gigabotan',
#  'Toast®',
#  'ХЭЙ КАППА КАППА Х',
#  'Rocco - Davaide and conquer',
#  'Justin Timbersaw',
#  'pePito´',
#  'Mbobo',
#  'L',
#  'skijunkie',
#  '12',
#  'Slap0r',
#  'change drug policy!!',
#  'marcek',
#  '[A]dmiral Bullshit',
#  '[W]',
#  'Sartre',
#  'Anomander Rake',
#  'Visigoth',
#  '♥ SugarGliderLove ♥',
#  'zxc',
#  'Saltz',
#  'Ti Eo Ti Em',
#  'Sneagle',
#  'Descent',
#  'David K',
#  'K P A C U B O',
#  'Nguyễn Kim Nhật Huy [MUTED]',
#  'EXO.DO.BigBronx',
#  'ALWAYSWANNAFLY',
#  'Evert',
#  'Kix 7x',
#  'Mika Anchornen',
#  'JukeGyllenhaal',
#  'Rebellion-SVK',
#  '.Bench',
#  'LUSHLIFE',
#  'SheVeeN',
#  'Ravushimo',
#  'Nico',
#  'Gerrow',
#  'WEE WILKINS WILLIAM',
#  'Shacklz',
#  'Dota 2 Psychologist',
#  'Play it again Sam',
#  'Meliodas',
#  'Midnight',
#  'KallePlanka',
#  'Albyzai',
#  'Alien',
#  '██████████�',
#  'Mlcrosoft',
#  's4tarash',
#  'the real roo',
#  'Dayew',
#  'Jesus Christ',
#  'Kitty',
#  'kgeekay',
#  'Acrutix',
#  'ihylmn',
#  'Crash',
#  'Asperg',
#  'Fly',
#  'Ｓｈｏｋａｒ',
#  'Spirit',
#  'Jk, the Resilience ₪',
#  'Bubbles',
#  'Reaper.BMTS',
#  'Zeenix',
#  "Porky's Butthole",
#  'Balanced Disco Pony',
#  'kami-sama',
#  'Satan',
#  'DD',
#  'Melon Juny[A]r',
#  'Peter',
#  'Nightmare',
#  'John',
#  'ghost',
#  'Kabuki warrior',
#  'a-FiZL',
#  'DarkPhoenix',
#  '¯\\_(ツ)_/¯',
#  ...]

# %% [markdown]
# ## Select chats and matches of frequently played players

# %%
chat = pd.read_csv('../data/chat_original.csv')

# %%
chat.dropna(inplace = True)

# %% [markdown]
# ### Select chats of frequently players

# %%
chat_freq = chat[chat['unit'].isin(freq_user_id)]

# %%
chat_freq.nunique()
# Out:
# match_id    24503
# key         93923
# slot           10
# time         5001
# unit         1807
# dtype: int64

# %% [markdown]
# There are 24503 matches, 93293 chat, and 1807 players.

# %% [markdown]
# #### Profanity Check

# %%
chat_freq.isnull().sum()
# Out:
# match_id    0
# key         0
# slot        0
# time        0
# unit        0
# dtype: int64

# %%
chat_freq['pf'] = predict(chat_freq['key'])

# %% [markdown]
# ### Replace match_id with unique values

# %% [markdown]
# Reassign match id by order

# %%
unique_match_id = list(range(chat_freq['match_id'].nunique()))

# %% [markdown]
# Unique match id list

# %%
freq_id_match_list = list(chat_freq['match_id'].drop_duplicates())

# %% [markdown]
# Overwrite match id

# %%
res = dict(zip(freq_id_match_list, unique_match_id))

# %%
chat_freq['match_id'] = chat_freq['match_id'].map(res)

# %% [markdown]
# ## Reshape Dataframe

# %% [markdown]
# ### Select columns required for analysis

# %%
df_freq = chat_freq[['unit', 'pf', 'match_id', 'time']]

# %% [markdown]
# ### Restructure dataframe

# %%
df_freq = df_freq.groupby(['match_id', 'unit']).sum()

# %% [markdown]
# ### Reset Index

# %%
df_freq = df_freq.reset_index()

# %% [markdown]
# ## Function for restructurizing dataframe for SNA: Need source, receiver, and weight

# %% [markdown]
# ### Reshape data:
# * Source(those who spoke abusive language),
# * Target(those who listen to abusive language during the match),
# * pf(sum of the abusive language produced during the match),
# * match_id_val(match_id)

# %%
df_freq_draft = []

for match_id in freq_id_match_list:
    df_by_match_id = df_freq[df_freq['match_id'] == match_id]
    receiver = df_by_match_id['unit'].to_list()
    source = df_by_match_id.loc[df_by_match_id['pf'] >= 1]['unit']
    pf = df_by_match_id.loc[df_by_match_id['pf'] >= 1]['pf']
    match_id_val = df_by_match_id['match_id']

    
    
    if len(df_by_match_id) != 0:
        source_val = list(np.repeat(source, len(receiver)))
        pf_val = list(np.repeat(pf, len(receiver)))

    source_list = list(zip(source_val, receiver, pf_val, match_id_val))
    
    df_freq_draft.extend(source_list)

# %%
df_freq_draft
# Out:
# [('Monkey', 'Kira', 1, 0),
#  ('Monkey', 'Monkey', 1, 0),
#  ('Joe', 'Joe', 2, 7),
#  ('Kappa', 'Kappa', 1, 18),
#  ('4Head', '4Head', 1, 40),
#  ('feeder', '._.', 1, 71),
#  ('feeder', 'feeder', 1, 71),
#  ('Axosh', 'Axosh', 4, 77),
#  (':D', ':D', 2, 82),
#  ('Miracle-', '4Head', 1, 86),
#  ('Miracle-', 'Miracle-', 1, 86),
#  ('Fluffy', 'Fluffy', 1, 121),
#  ('Fluffy', 'Horse', 1, 121),
#  ('Banyu', 'Banyu', 2, 132),
#  ('Casto', 'Casto', 1, 134),
#  ('Arbi', 'Arbi', 1, 144),
#  ('Arbi', 'Chill', 1, 144),
#  ('Arbi', 'Psycho', 1, 144),
#  ('Nuker', 'Nuker', 4, 178),
#  ('Stallon', 'Reaper', 1, 179),
#  ('Stallon', 'Stallon', 1, 179),
#  ('TINKLES', 'TINKLES', 1, 180),
#  ('@hiro', '@hiro', 1, 187),
#  ('#ano.Ainsley Kek', '#ano.Ainsley Kek', 1, 204),
#  ('#ano.Ainsley Kek', 'Dictionaries', 1, 204),
#  ('Jesus', 'Jesus', 6, 207),
#  ('Ho랑이', 'Ho랑이', 1, 208),
#  ('Ho랑이', 'XXX', 1, 208),
#  ('Tensai >.<', 'Tensai >.<', 4, 239),
#  ('Hyy', '...', 1, 240),
#  ('Hyy', 'Hyy', 1, 240),
#  ('Hyy', 'Lặng Lẽ Tổn Thương', 1, 240),
#  ('Hyy', 'Sleeping_[D]og', 1, 240),
#  ('Hyy', 'bwew', 1, 240),
#  ('Arbi', 'Arbi', 1, 242),
#  ('Arbi', 'Rawdog', 1, 242),
#  ('yolowarrior', 'yolowarrior', 1, 267),
#  ('The Seven Deadly Sins', 'The Seven Deadly Sins', 1, 274),
#  ('Prince of Excrement', 'Prince of Excrement', 1, 283),
#  ('< blank >', '< blank >', 1, 286),
#  ('Akashi Seijuro', 'Akashi Seijuro', 1, 289),
#  ('Urist', 'Urist', 1, 290),
#  ('Ahov', 'Ahov', 1, 300),
#  ('Kappa', 'Kappa', 1, 301),
#  ('Skiller', 'Skiller', 2, 305),
#  ('LOVE-is-EZ but I hate you', 'LOVE-is-EZ but I hate you', 1, 306),
#  ('Harry', 'Harry', 1, 307),
#  ('Harry', 'Saitama', 1, 307),
#  ('Ellimist', 'Ellimist', 1, 325),
#  ('Ellimist', 'Shade', 1, 325),
#  ('????????', '????????', 1, 326),
#  ('????????', 'Tensai >.<', 1, 326),
#  ('sojtucker', 'sojtucker', 2, 327),
#  ('Lepo Lepo', 'A Wild Smurf', 1, 331),
#  ('Lepo Lepo', 'Lepo Lepo', 1, 331),
#  ('Lepo Lepo', 'Memories', 1, 331),
#  ('Lepo Lepo', 'Spooderman', 1, 331),
#  ('Smegma', 'Smegma', 1, 332),
#  ('Thomas The Dank Engine', 'Thomas The Dank Engine', 1, 342),
#  ('yolowarrior', 'yolowarrior', 1, 345),
#  ('AirmailMRCOOL', 'AirmailMRCOOL', 1, 346),
#  ('ABC', 'ABC', 2, 357),
#  ('Deez_Nuts', 'Deez_Nuts', 7, 377),
#  ('Pineapple KAMIKAZE', '.', 5, 381),
#  ('Pineapple KAMIKAZE', 'Pineapple KAMIKAZE', 5, 381),
#  ('Nijbu', 'Nijbu', 1, 387),
#  ('TINKLES', 'Lelouch', 4, 397),
#  ('TINKLES', 'TINKLES', 4, 397),
#  ('TINKLES', '†', 4, 397),
#  ('TINKLES', '攀登', 4, 397),
#  ('aTly', 'aTly', 1, 399),
#  ('KN.4ever.♥™®', 'KN.4ever.♥™®', 1, 401),
#  ('Zero97M', 'Zero97M', 1, 404),
#  ('Snipe Desu~', 'Snipe Desu~', 1, 407),
#  ('Spazzkid', 'Spazzkid', 1, 418),
#  ('Tensai >.<', '123', 3, 420),
#  ('Tensai >.<', 'Tensai >.<', 3, 420),
#  ('Ｂ Ｅ Ｎ Ｎ', 'Ｂ Ｅ Ｎ Ｎ', 1, 421),
#  ('...', '...', 2, 423),
#  ('...', 'Hatsune Miku', 2, 423),
#  ('Ri', 'Ri', 1, 433),
#  ('Dr.X', 'Dr.X', 5, 434),
#  ('Dr.X', 'w33', 5, 434),
#  ('soy papá', 'soy papá', 1, 450),
#  ('yolowarrior', 'yolowarrior', 1, 452),
#  ('0.0', '0.0', 1, 455),
#  ('A', '..', 1, 456),
#  ('A', 'A', 1, 456),
#  ('Sleeping_[D]og', 'Hyy', 2, 460),
#  ('Sleeping_[D]og', 'JOHN CENA', 2, 460),
#  ('Sleeping_[D]og', 'Sleeping_[D]og', 2, 460),
#  ('Sleeping_[D]og', 'bwew', 2, 460),
#  ('Pineapple KAMIKAZE', 'Aeon', 6, 476),
#  ('Pineapple KAMIKAZE', 'Pineapple KAMIKAZE', 6, 476),
#  ('< blank >', '< blank >', 1, 477),
#  ('< blank >', 'Panda', 1, 477),
#  ('M', '...............................', 1, 490),
#  ('M', 'M', 1, 490),
#  ('Tensai >.<', 'Tensai >.<', 3, 499),
#  ('Mark', 'Mark', 3, 509),
#  ('CHI LONG QUA', 'CHI LONG QUA', 1, 513),
#  ('Snipe Desu~', 'Snipe Desu~', 1, 523),
#  ('1017', '1017', 1, 530),
#  ('Onions123', 'Onions123', 3, 533),
#  ('Onions123', 'kellyMONKEYS', 3, 533),
#  ('Arts', 'Arts', 2, 537),
#  ('Rage', 'Rage', 1, 546),
#  ('Captain America', 'Captain America', 1, 565),
#  ('Captain America', 'Law', 1, 565),
#  ('Captain America', 'Thanatael', 1, 565),
#  ('Captain America', 'cocodino', 1, 565),
#  ('[STR].MissBug', '[STR].MissBug', 1, 569),
#  ('Ｂ Ｅ Ｎ Ｎ', 'Ｂ Ｅ Ｎ Ｎ', 1, 571),
#  ('Logic', 'Logic', 1, 573),
#  ('Logic', 'PUNX', 1, 573),
#  ('Jiten', 'JAFAR', 1, 579),
#  ('Jiten', 'Jiten', 1, 579),
#  ('#ano.Ainsley Kek', '#ano.Ainsley Kek', 1, 583),
#  ('CHI LONG QUA', 'CHI LONG QUA', 1, 590),
#  ('dream is ded', 'LOVE-is-EZ but I hate you', 1, 593),
#  ('dream is ded', 'dream is ded', 1, 593),
#  ("[EE's Disciple]", "[EE's Disciple]", 1, 594),
#  ('Rawdog', 'Rawdog', 2, 596),
#  ('tehdilgerer', 'tehdilgerer', 1, 597),
#  ('RED', 'RED', 4, 605),
#  ('RED', 'w/e', 4, 605),
#  ('RED', 'yolowarrior', 4, 605),
#  ('asdf', 'Apple', 1, 608),
#  ('asdf', 'asdf', 1, 608),
#  ('bneutrality', 'bneutrality', 1, 610),
#  ('400 Lux', '400 Lux', 1, 617),
#  ('322', '322', 1, 632),
#  ('322', 'Saitama', 1, 632),
#  ('Black', 'Black', 1, 639),
#  ('BANZAI', 'BANZAI', 1, 643),
#  ('Jesus', 'Jesus', 2, 654),
#  ('Jesus', 'LOL', 2, 654),
#  ('Ceyler', 'Ceyler', 1, 656),
#  ('Ceyler', 'QQ', 1, 656),
#  ('Gary', 'Alucard', 2, 670),
#  ('Gary', 'Gary', 2, 670),
#  ('Baxter', 'Baxter', 2, 677),
#  ('Baxter', 'Madara', 2, 677),
#  ('4Head', '4Head', 1, 684),
#  ('4Head', '=)', 1, 684),
#  ('AirmailMRCOOL', 'AirmailMRCOOL', 1, 685),
#  ('AirmailMRCOOL', 'Noob', 1, 685),
#  ('bneutrality', 'bneutrality', 1, 691),
#  ('Fred', 'Fred', 1, 697),
#  ('Fred', 'Ｂ Ｅ Ｎ Ｎ', 1, 697),
#  ("[EE's Disciple]", "[EE's Disciple]", 6, 713),
#  ('West Street Variety', 'Valar Morghulis', 1, 727),
#  ('West Street Variety', 'West Street Variety', 1, 727),
#  ('1', '1', 1, 729),
#  ('1', '?', 1, 729),
#  ('1', 'Jerry', 1, 729),
#  ('Rorschach', '0.0', 2, 739),
#  ('Rorschach', '9/10', 2, 739),
#  ('Rorschach', 'Rorschach', 2, 739),
#  ('Nigga', 'Nigga', 1, 745),
#  ('Mottley', 'Mottley', 1, 751),
#  ('Death', 'Death', 1, 773),
#  ('Death', 'Psycho', 1, 773),
#  ('Nero', 'Andy', 1, 777),
#  ('Nero', 'Nero', 1, 777),
#  ('Skayl', 'Skayl', 3, 793),
#  ('sojtucker', 'sojtucker', 1, 800),
#  ('Lucifer', 'Lucifer', 2, 802),
#  ('Lucifer', 'trollfederer', 2, 802),
#  ('Ez', 'Ez', 1, 808),
#  ('Gucci MagiK', 'Gucci MagiK', 1, 809),
#  ('Myrmidon', 'Myrmidon', 1, 810),
#  ('Myrmidon', 'yolo', 1, 810),
#  ('The Joy of Feeding', 'The Joy of Feeding', 1, 813),
#  ('SAITAMA', 'SAITAMA', 2, 826),
#  ('sad', 'sad', 4, 841),
#  ('Sorry', 'Sorry', 1, 850),
#  ('Sorry', 'The Seven Deadly Sins', 1, 850),
#  ('D4D.EldestDad.420', 'D4D.EldestDad.420', 2, 863),
#  ('D4D.EldestDad.420', 'One Punch!', 2, 863),
#  ('rKaiser', 'YOLO', 1, 864),
#  ('rKaiser', 'rKaiser', 1, 864),
#  ('소녀시대-김태연', '소녀시대-김태연', 4, 866),
#  ('Neo', 'Neo', 1, 867),
#  ("[EE's Disciple]", "[EE's Disciple]", 3, 870),
#  ('kRAnk-.-', 'kRAnk-.-', 2, 876),
#  ('1017', '1017', 1, 924),
#  ('1017', 'Mayhem', 1, 924),
#  ('Nexr', 'Nexr', 1, 930),
#  ('Nexr', 'Totti#Smauking dat Seaweed', 1, 930),
#  ('xD', 'xD', 1, 936),
#  ('haha', 'haha', 2, 953),
#  ('Emil', 'Emil', 1, 954),
#  ('D.', 'D.', 1, 956),
#  ('D.', 'NB', 1, 956),
#  ('Max', 'Max', 2, 966),
#  ('Сын Собаки', 'Сын Собаки', 1, 969),
#  ('RANDOM OR RIOT', 'RANDOM OR RIOT', 1, 978),
#  ('Mr. Bay', 'Mr. Bay', 1, 982),
#  ('Psycho', 'Psycho', 13, 994),
#  ('Lets get this underway', 'Lets get this underway', 1, 1006),
#  ('???', '???', 1, 1009),
#  ('???', 'leasey^', 1, 1009),
#  ('Pд††дЯ', 'Pд††дЯ', 1, 1019),
#  ('Uldred', 'Uldred', 2, 1023),
#  ('Uldred', 'asd', 2, 1023),
#  ('Morty', 'Morty', 3, 1040),
#  ('J.', 'J.', 1, 1041),
#  ('J.', 'brodericoh', 1, 1041),
#  ('Thunderdyne', 'Thunderdyne', 1, 1049),
#  ('No more heroes', 'Kira', 1, 1050),
#  ('No more heroes', 'No more heroes', 1, 1050),
#  ('HolyMoly -QsQ-', 'HolyMoly -QsQ-', 1, 1052),
#  ('AirmailMRCOOL', 'AirmailMRCOOL', 1, 1055),
#  ('Kirito', 'Kirito', 2, 1057),
#  ('Kirito', 'Mortal Vengeance', 2, 1057),
#  ('Donk', 'Donk', 1, 1099),
#  ('..', '..', 1, 1107),
#  ('22', '22', 1, 1115),
#  ('22', 'DoctorVox', 1, 1115),
#  ('Grom', 'Grom', 3, 1119),
#  ('Grom', 'Jon', 3, 1119),
#  ('Coco', 'Coco', 1, 1120),
#  ('Coco', 'K', 1, 1120),
#  ('D4D.EldestDad.420', 'D4D.EldestDad.420', 2, 1123),
#  ('D4D.EldestDad.420', 'Hans Moleman', 2, 1123),
#  ('Sweet TittyMo', 'Sweet TittyMo', 1, 1127),
#  ('Hakuna Matata', 'Hakuna Matata', 2, 1128),
#  ('Myrmidon', 'Myrmidon', 1, 1129),
#  ('Adlet Mayer', 'Adlet Mayer', 3, 1137),
#  ('Fayher', 'Fayher', 2, 1143),
#  ('Fayher', 'Rampage', 2, 1143),
#  ('x-0ne (G.O.D)', 'x-0ne (G.O.D)', 1, 1148),
#  ('1738', '1738', 1, 1152),
#  ('1738', 'MïќE LtR', 1, 1152),
#  ('1738', 'Tahurtz', 1, 1152),
#  ('1738', 'ausoi', 1, 1152),
#  ('Dontores`', 'Dontores`', 3, 1158),
#  ('Dontores`', 'GeGe', 3, 1158),
#  ('bneutrality', 'bneutrality', 2, 1166),
#  ('The Joy of Feeding', 'The Joy of Feeding', 1, 1168),
#  ('Petchef', 'Petchef', 1, 1179),
#  ('Vanilla Bear', 'Vanilla Bear', 2, 1191),
#  ('Warrior', 'Hugs from Jewland', 1, 1197),
#  ('Warrior', 'Warrior', 1, 1197),
#  ('Bob Ross', 'Bob Ross', 1, 1202),
#  ('Bob Ross', '「Kushi」', 1, 1202),
#  ('Fox', 'Fox', 1, 1209),
#  ('wλrthen', 'wλrthen', 1, 1218),
#  ('5to7', '5to7', 1, 1233),
#  ('Psycho', 'Psycho', 3, 1235),
#  ('Ellimist', 'Ellimist', 2, 1241),
#  ('Ellimist', 'Pyro', 2, 1241),
#  ('Ellimist', 'Shade', 2, 1241),
#  ('Ellimist', 'StarScream -', 2, 1241),
#  ('Trollypops', 'Trollypops', 1, 1272),
#  ('Đưa Nhau Đi Feed', 'Đưa Nhau Đi Feed', 2, 1273),
#  ('Metfly7', 'Metfly7', 2, 1276),
#  ('zzzzzzzzz', 'zzzzzzzzz', 1, 1302),
#  ('Skiper', 'Skiper', 1, 1309),
#  ('Seatech', 'Seatech', 3, 1326),
#  ('Rain', 'Rain', 1, 1330),
#  ('直美 Naomi', '直美 Naomi', 1, 1333),
#  ('BuRN', 'BuRN', 2, 1336),
#  ('xWinkler', 'xWinkler', 5, 1341),
#  ('Jana', 'Jana', 1, 1352),
#  ('MaSta', 'MaSta', 2, 1364),
#  ('gorgeous', 'gorgeous', 1, 1366),
#  ('Windalfr', 'Flex Luthor', 1, 1374),
#  ('Windalfr', 'Windalfr', 1, 1374),
#  ('Just Do It!', 'Just Do It!', 1, 1384),
#  ('322', '322', 1, 1392),
#  ('322', 'Boobs-chan', 1, 1392),
#  ('322', 'Moe-Chan', 1, 1392),
#  ('twitch.tv/pesdota #Hope', 'G_G', 2, 1404),
#  ('twitch.tv/pesdota #Hope', 'YBP', 2, 1404),
#  ('twitch.tv/pesdota #Hope', 'twitch.tv/pesdota #Hope', 2, 1404),
#  ('MID', 'MID', 1, 1416),
#  ('Bob Ross', 'Bob Ross', 1, 1418),
#  ('Svarog', 'Svarog', 2, 1420),
#  ('Ragnar', 'Omega', 1, 1422),
#  ('Ragnar', 'Ragnar', 1, 1422),
#  ('Dontores`', 'Dontores`', 1, 1423),
#  ('Dontores`', 'Lucifer', 1, 1423),
#  ('Zeeks', 'Zeeks', 1, 1425),
#  ('Bum bum - Bot', 'Bum bum - Bot', 1, 1428),
#  ('Bum bum - Bot', 'Sugy', 1, 1428),
#  ('Terpcasl', 'Terpcasl', 2, 1460),
#  ('Tryhard', 'Tryhard', 1, 1466),
#  ("Blacque The Lil' Rooster", "Blacque The Lil' Rooster", 1, 1469),
#  ('Warrior', 'Hugs from Jewland', 1, 1480),
#  ('Warrior', 'Warrior', 1, 1480),
#  ('DK', 'DK', 1, 1484),
#  ('XO', 'Richard', 2, 1490),
#  ('XO', 'XO', 2, 1490),
#  ('Jana', 'Jana', 4, 1494),
#  ('Goku', 'Etherus', 1, 1512),
#  ('Goku', 'Goku', 1, 1512),
#  ('Chief', '.', 1, 1514),
#  ('Chief', 'Chief', 1, 1514),
#  ('Chief', 'Thejoyofdota FeelsBadMan', 1, 1514),
#  ('klaytog', 'RuSup', 2, 1528),
#  ('klaytog', 'klaytog', 2, 1528),
#  ('JUKE NUKEM', 'JUKE NUKEM', 1, 1532),
#  ('Road to 5k', 'Road to 5k', 4, 1552),
#  ('bneutrality', 'bneutrality', 1, 1553),
#  ('bneutrality', 'noob', 1, 1553),
#  ('Slap0r', 'Slap0r', 1, 1579),
#  ('Slap0r', 'change drug policy!!', 1, 1579),
#  ('Slap0r', 'marcek', 1, 1579),
#  ('[W]', '[A]dmiral Bullshit', 9, 1580),
#  ('[W]', '[W]', 9, 1580),
#  ('????????', '????????', 1, 1581),
#  ('????????', 'G_G', 1, 1581),
#  ('????????', 'twitch.tv/pesdota #Hope', 1, 1581),
#  ('David K', 'David K', 1, 1605),
#  ('.Atheris', '.Atheris', 1, 1609),
#  ('.Atheris', 'XO', 1, 1609),
#  ('Ceyler', 'Ceyler', 2, 1615),
#  ('[DeadWithPain]', '[DeadWithPain]', 1, 1617),
#  ('321', '321', 2, 1628),
#  ('321', 'Rebellion-SVK', 2, 1628),
#  ('Just Do It!', 'Just Do It!', 1, 1633),
#  ('Gerrow', 'Gerrow', 1, 1643),
#  ('Fire', 'Fire', 2, 1646),
#  ('Shacklz', 'JOHN CENA', 1, 1650),
#  ('Shacklz', 'Shacklz', 1, 1650),
#  ('Bahmut', 'Bahmut', 1, 1653),
#  ('Bahmut', 'Jet', 1, 1653),
#  ('Λ', 'Λ', 2, 1659),
#  ('██████████�', 'Alien', 2, 1671),
#  ('██████████�', '██████████�', 2, 1671),
#  ('Ginko ギンコ', 'Ginko ギンコ', 1, 1676),
#  ('Glen', ':)', 2, 1685),
#  ('Glen', 'Funk You', 2, 1685),
#  ('Glen', 'Glen', 2, 1685),
#  ('David K', 'David K', 1, 1702),
#  ('Reaper.BMTS', 'Reaper.BMTS', 1, 1720),
#  ('qweqwe', 'qweqwe', 1, 1725),
#  ('Dragnipur', 'Dragnipur', 1, 1726),
#  ('Dragnipur', 'Mighty Manatee', 1, 1726),
#  ('Dragnipur', 'Ѵirtualghost', 1, 1726),
#  ('Brotherman Bill', 'Brotherman Bill', 1, 1743),
#  ('whatever', 'Kabuki warrior', 1, 1752),
#  ('whatever', 'whatever', 1, 1752),
#  ('Pineapple KAMIKAZE', 'Pineapple KAMIKAZE', 1, 1753),
#  ('¯\\_(ツ)_/¯', 'G. R. T.', 1, 1760),
#  ('¯\\_(ツ)_/¯', '¯\\_(ツ)_/¯', 1, 1760),
#  ('Brian', 'Brian', 3, 1761),
#  ('Brian', 'Descent', 3, 1761),
#  ('Myrmidon', 'Myrmidon', 1, 1768),
#  ('Fire', 'Fire', 2, 1787),
#  ('Max Tryhard', 'Max Tryhard', 1, 1809),
#  ('JMT', 'JMT', 1, 1813),
#  ('Urist', 'Urist', 2, 1821),
#  ('Uriziel', 'Uriziel', 1, 1830),
#  ('Internet Explorer', 'Internet Explorer', 1, 1835),
#  ('Internet Explorer', 'Master', 1, 1835),
#  ('Internet Explorer', 'Tobi', 1, 1835),
#  ('John Cena', 'John Cena', 1, 1845),
#  ('JUKE NUKEM', 'JUKE NUKEM', 3, 1848),
#  ('Allison', '5to7', 2, 1852),
#  ('Allison', 'Allison', 2, 1852),
#  ('Up-iN*tHe.AiR', 'Up-iN*tHe.AiR', 2, 1861),
#  ('Up-iN*tHe.AiR', 'killzone', 2, 1861),
#  ('Pingouin', 'Inigo', 3, 1872),
#  ('Pingouin', 'Pingouin', 3, 1872),
#  ('Elvis', 'Elvis', 1, 1881),
#  ('bneutrality', 'bneutrality', 1, 1892),
#  ('bneutrality', 'hehe', 1, 1892),
#  ('Urgel', 'Urgel', 1, 1895),
#  ('RyuKen', 'RyuKen', 4, 1897),
#  ('Rick Sanchez', 'Rick Sanchez', 2, 1900),
#  ('s4tarash', 'Mlcrosoft', 1, 1906),
#  ('s4tarash', 's4tarash', 1, 1906),
#  ('Titane', 'Titane', 1, 1913),
#  ('Titane', 'wizn', 1, 1913),
#  ('Roronoa Zoro', 'Roronoa Zoro', 1, 1916),
#  ('Alison', 'Alison', 5, 1931),
#  ('Alison', 'Chopper', 5, 1931),
#  ('Alison', 'El Dude', 5, 1931),
#  ('Bahmut', 'Bahmut', 2, 1936),
#  ('?', '?', 2, 1939),
#  ('Ragnar', 'Heisenberg', 1, 1961),
#  ('Ragnar', 'Ragnar', 1, 1961),
#  ('BuRN', 'BuRN', 10, 1982),
#  ('123', '123', 1, 1990),
#  ('MID OR FEED', 'MID OR FEED', 1, 2018),
#  ('Xin', 'Xin', 1, 2025),
#  ('Xin', 'haat.by', 1, 2025),
#  ('Hi, Can I have mossarella stick',
#   'Hi, Can I have mossarella stick',
#   1,
#   2029),
#  ('Monkster', 'FOX', 1, 2031),
#  ('Monkster', 'Monkster', 1, 2031),
#  ('.Bench', '.Bench', 1, 2041),
#  ('KN.4ever.♥™®', 'KN.4ever.♥™®', 1, 2044),
#  ('Psycho', 'Psycho', 5, 2054),
#  ('Aruu10', 'Aruu10', 1, 2060),
#  ('Clueless', 'Clueless', 1, 2076),
#  ('Jc', 'Happy', 1, 2080),
#  ('Jc', 'Jc', 1, 2080),
#  ('Hard Mode', 'CHI LONG QUA', 1, 2089),
#  ('Hard Mode', 'Hard Mode', 1, 2089),
#  ('Dark', 'Clockwork', 1, 2111),
#  ('Dark', 'Dark', 1, 2111),
#  ('GG', 'GG', 1, 2114),
#  ('GG', 'Saitama', 1, 2114),
#  ('5to7', '5to7', 1, 2125),
#  ('BuRN', 'BuRN', 1, 2127),
#  ('(have fun, pal)', '(have fun, pal)', 1, 2137),
#  ('Bob Ross', 'Bob Ross', 3, 2151),
#  ('KappaRoss', 'KappaRoss', 1, 2155),
#  ('KappaRoss', 'nice la', 1, 2155),
#  ('Fire', 'Fire', 1, 2168),
#  ('Miley', 'Clouds', 2, 2172),
#  ('Miley', 'Miley', 2, 2172),
#  ('Miley', 'jd', 2, 2172),
#  ('Sorry', 'Sorry', 12, 2173),
#  ('Shrekendrick Lamar', 'Shrekendrick Lamar', 1, 2174),
#  ('JUMPMAN', 'JUMPMAN', 1, 2175),
#  ('SQWERTY', 'SQWERTY', 1, 2176),
#  ('Mlcrosoft', 'Mlcrosoft', 7, 2182),
#  ('Mlcrosoft', 's4tarash', 7, 2182),
#  ('Mlcrosoft', 'your4', 7, 2182),
#  ('Nando', '< blank >', 1, 2184),
#  ('Nando', 'Nando', 1, 2184),
#  ('Jim Carry', 'Jim Carry', 2, 2191),
#  ('Play it again Sam', 'Play it again Sam', 4, 2192),
#  ('DKD', 'DKD', 1, 2210),
#  ('Dr.Sexy', 'Dr.Sexy', 1, 2212),
#  ('Flash', 'Flash', 1, 2213),
#  ('Uldred', 'Uldred', 1, 2239),
#  ('HolyMoly -QsQ-', 'HolyMoly -QsQ-', 1, 2250),
#  ('Hades', 'Hades', 2, 2251),
#  ('Hades', 'MangoCrysis™', 2, 2251),
#  ('BB', 'BB', 1, 2258),
#  ('bonjour pizdec', 'bonjour pizdec', 2, 2261),
#  ('Darbax', 'Darbax', 1, 2298),
#  ('carry please ty', 'Kirito', 1, 2306),
#  ('carry please ty', 'carry please ty', 1, 2306),
#  ('gohanaragorn', 'gohanaragorn', 1, 2311),
#  ('Bob Ross', 'Bob Ross', 1, 2312),
#  ('Av', 'Av', 1, 2316),
#  ('Av', 'Superior Highlander Genes', 1, 2316),
#  ('leviosaw', 'Drake', 2, 2342),
#  ('leviosaw', 'Jack Sparrow', 2, 2342),
#  ('leviosaw', 'leviosaw', 2, 2342),
#  ('Yung Lean', 'Yung Lean', 1, 2344),
#  ('ice', 'BabyRage', 1, 2354),
#  ('ice', 'ice', 1, 2354),
#  ('Starky', 'Starky', 2, 2359),
#  ('Max Guymer', 'Max Guymer', 3, 2365),
#  ('Bunny of Doom', 'Bunny of Doom', 1, 2366),
#  ('Bunny of Doom', 'U OK NERD?', 1, 2366),
#  ('gibe da Weekend, b0ss', 'gibe da Weekend, b0ss', 1, 2374),
#  ('Caped Baldy', 'Caped Baldy', 1, 2375),
#  ('Caped Baldy', 'zzzzzzzzz', 1, 2375),
#  ('Hades', 'Hades', 1, 2382),
#  ('Apache', 'Apache', 1, 2387),
#  ('Syy', 'Syy', 1, 2401),
#  ('JasCaLL', 'JasCaLL', 3, 2416),
#  ('JasCaLL', 'Varian Wrynn', 3, 2416),
#  ('Mlcrosoft', 'Mlcrosoft', 1, 2418),
#  ('Mlcrosoft', 's4tarash', 1, 2418),
#  ('Mlcrosoft', 'your4', 1, 2418),
#  ('tunes', 'tunes', 1, 2432),
#  ('Matt', 'Matt', 3, 2433),
#  ('[A]', '[A]', 1, 2443),
#  ('Dragnipur', 'Dragnipur', 4, 2447),
#  ('BuRN', 'BuRN', 1, 2469),
#  ('Michael', 'Michael', 1, 2473),
#  ('kaztah', '///', 2, 2475),
#  ('kaztah', 'Bulls_Eye', 2, 2475),
#  ('kaztah', 'kaztah', 2, 2475),
#  ('Mortal Vengeance', 'Mortal Vengeance', 1, 2481),
#  ('Audible Chocolate', 'Audible Chocolate', 1, 2484),
#  ('Boo', 'Boo', 1, 2505),
#  ('AtField.Barba', 'AtField.Barba', 2, 2507),
#  ('AtField.Barba', 'rYaiEn', 2, 2507),
#  ('Predator', 'Predator', 1, 2518),
#  ('Glen', 'Funk You', 4, 2532),
#  ('Glen', 'Glen', 4, 2532),
#  ('.', '.', 1, 2536),
#  ('Roy', 'Roy', 1, 2540),
#  ('Fish Roe Man', 'Fish Roe Man', 1, 2543),
#  ('Descent', 'Descent', 1, 2544),
#  ('Descent', 'Nazarij', 1, 2544),
#  ('Max Guymer', 'Max Guymer', 3, 2548),
#  ('Do --', 'Do --', 1, 2551),
#  ('JUKE NUKEM', 'JUKE NUKEM', 1, 2593),
#  ('Clueless', 'Clueless', 1, 2604),
#  ('...', '...', 1, 2613),
#  ('Kanada', 'Kanada', 1, 2617),
#  ('KKK', 'KKK', 2, 2620),
#  ('KKK', 'method in my madness', 2, 2620),
#  ('.', '.', 1, 2623),
#  ('.', 'yolo', 1, 2623),
#  ('Av', 'Av', 1, 2633),
#  ('Av', 'soy papá', 1, 2633),
#  ('Cletus', 'Cletus', 1, 2642),
#  ('Omega', 'Omega', 1, 2647),
#  ('Prince of Excrement', 'Prince of Excrement', 5, 2652),
#  ('ez', 'ez', 1, 2660),
#  ('JukeSkywalker', 'JukeGyllenhaal', 2, 2664),
#  ('JukeSkywalker', 'JukeSkywalker', 2, 2664),
#  ('JukeSkywalker', 'Martin Luther King Juker', 2, 2664),
#  ('W', 'Teleport Scroll Expert', 1, 2707),
#  ('W', 'W', 1, 2707),
#  ('Justice', 'Justice', 1, 2719),
#  ('Justice', 'Medivh', 1, 2719),
#  ('baKKhus', 'baKKhus', 3, 2722),
#  ('Miska', 'Miska', 1, 2724),
#  ('Miska', 'SD.merlin', 1, 2724),
#  ('Miska', 'Tallcat', 1, 2724),
#  ('Miska', 'The Boy', 1, 2724),
#  ('Rocco - Davaide and conquer', '-25', 2, 2740),
#  ('Rocco - Davaide and conquer', 'Rocco - Davaide and conquer', 2, 2740),
#  ('Thomas The Dank Engine', 'Thomas The Dank Engine', 3, 2742),
#  ('N A', 'N A', 3, 2753),
#  ('Inspector Norse', 'Inspector Norse', 2, 2760),
#  ('Marymar♥', '< blank >', 1, 2762),
#  ('Marymar♥', 'Marymar♥', 1, 2762),
#  ('Marymar♥', 'Psycho', 1, 2762),
#  ('Bob Ross', 'Bob Ross', 1, 2775),
#  ('NotLikeThis', 'Fire', 2, 2784),
#  ('NotLikeThis', 'NotLikeThis', 2, 2784),
#  ('Monster', 'G_G', 3, 2797),
#  ('Monster', 'Monster', 3, 2797),
#  ('Vroksnak', 'Vroksnak', 2, 2823),
#  ('ZorN', 'Hunter', 1, 2844),
#  ('ZorN', 'ZorN', 1, 2844),
#  ('Nero', 'Nero', 1, 2868),
#  ('Matt', 'Matt', 1, 2870),
#  ('Prince of Excrement', 'Prince of Excrement', 2, 2882),
#  ('Firefix', 'Firefix', 1, 2887),
#  ('Saitama', 'Saitama', 1, 2903),
#  ('Saitama', 'Silence', 1, 2903),
#  ('Vynil | Zyn', 'Vynil | Zyn', 1, 2906),
#  ('-25', '-25', 1, 2912),
#  ('Freak Show', 'Freak Show', 1, 2922),
#  ('Peter', 'Peter', 1, 2925),
#  ('XD', 'XD', 2, 2931),
#  ('Syy', 'Syy', 8, 2938),
#  ('baKKhus', 'baKKhus', 1, 2958),
#  ('werling44', 'new beginnings', 1, 2978),
#  ('werling44', 'werling44', 1, 2978),
#  ('Carnage', 'Carnage', 2, 2984),
#  ('Garam', 'ALWAYSWANNAFLY', 1, 2985),
#  ('Garam', 'Garam', 1, 2985),
#  ('Emperor', 'Emperor', 1, 3007),
#  ('Nexr', 'Nexr', 4, 3014),
#  ('Nexr', 'Nirvana', 4, 3014),
#  ('Justice', 'Justice', 1, 3025),
#  ('TINKLES', 'Butthole', 1, 3032),
#  ('TINKLES', 'Ho랑이', 1, 3032),
#  ('TINKLES', 'Nx3', 1, 3032),
#  ('TINKLES', 'TINKLES', 1, 3032),
#  ('FeelTheBern', 'FeelTheBern', 1, 3043),
#  ('aaron', 'Hi', 2, 3045),
#  ('aaron', 'aaron', 2, 3045),
#  ('adam', 'adam', 1, 3046),
#  ('Myth', 'Myth', 1, 3051),
#  ('Myth', 'Neo', 1, 3051),
#  ('Myth', 'Whatever', 1, 3051),
#  ('Spla$H', 'Spla$H', 1, 3054),
#  ('Assassin', 'Assassin', 1, 3056),
#  ('Assassin', 'noob', 1, 3056),
#  ('Axosh', 'Axosh', 1, 3061),
#  ('N A', 'Morgo', 3, 3067),
#  ('N A', 'N A', 3, 3067),
#  ('ALWAYSWANNADIE', 'ALWAYSWANNADIE', 7, 3074),
#  ('Michael', 'Hurfdurf', 2, 3075),
#  ('Michael', 'Michael', 2, 3075),
#  ('DIabOluS', 'DIabOluS', 1, 3080),
#  ('DIabOluS', 'Hero', 1, 3080),
#  ('popo', 'Jack "ppc" Pot', 2, 3086),
#  ('popo', 'popo', 2, 3086),
#  ('lmao', 'lmao', 1, 3087),
#  ('Vynil | Zyn', 'Vynil | Zyn', 1, 3110),
#  ('Snoopy', 'Snoopy', 3, 3111),
#  ('J.', '.', 1, 3113),
#  ('J.', 'J.', 1, 3113),
#  ('J.', 'Josh', 1, 3113),
#  ('Ephemeral', 'Ephemeral', 5, 3114),
#  ('Ephemeral', 'KappaPride', 5, 3114),
#  ('..', '..', 1, 3116),
#  ('Peter', 'Jeff', 3, 3120),
#  ('Peter', 'Peter', 3, 3120),
#  ('Hi, Can I have mossarella stick',
#   'Hi, Can I have mossarella stick',
#   2,
#   3123),
#  ('Garam', 'Garam', 1, 3128),
#  ('MingLee', 'Kirito', 1, 3140),
#  ('MingLee', 'MingLee', 1, 3140),
#  ('Keck³', 'Keck³', 1, 3147),
#  ('Snipe Desu~', 'Snipe Desu~', 1, 3175),
#  ('Smile', 'Smile', 2, 3176),
#  ('Smile', "What's Poppin'", 2, 3176),
#  ('RBLR.Marcutio', 'RBLR.Marcutio', 1, 3178),
#  ('RBLR.Marcutio', 'RBLR.dany fuckin heatley', 1, 3178),
#  ('RBLR.Marcutio', 'Rick Sanchez', 1, 3178),
#  ('Pд††дЯ', 'Pд††дЯ', 1, 3189),
#  ('Hans Moleman', 'Hans Moleman', 1, 3197),
#  ('CHI LONG QUA', 'CHI LONG QUA', 1, 3198),
#  ('Dracula', 'Dracula', 1, 3200),
#  ('Hey b0ss', 'Hey b0ss', 1, 3202),
#  ('BabyRage', 'BabyRage', 1, 3204),
#  ('Ragnar Lothbrok', 'Ragnar Lothbrok', 1, 3205),
#  ('Madara', 'Madara', 14, 3215),
#  ('D4D.EldestDad.420', '425', 1, 3221),
#  ('D4D.EldestDad.420', 'D4D.EldestDad.420', 1, 3221),
#  ('Psycho', 'Psycho', 2, 3222),
#  ('WADE !!', 'WADE !!', 2, 3265),
#  ('it looked bigger on snapchat', 'it looked bigger on snapchat', 3, 3277),
#  ('Vanity', 'Kain', 1, 3282),
#  ('Vanity', 'Vanity', 1, 3282),
#  ('General Stonewall Jukeson', 'General Stonewall Jukeson', 1, 3283),
#  ('General Stonewall Jukeson', 'JukeGyllenhaal', 1, 3283),
#  ('General Stonewall Jukeson', 'JukeSkywalker', 1, 3283),
#  ('General Stonewall Jukeson', 'Martin Luther King Juker', 1, 3283),
#  ('Valar Morghulis', 'Valar Morghulis', 1, 3287),
#  ("joker'sbestfriend", "joker'sbestfriend", 1, 3299),
#  ('Axosh', 'Axosh', 2, 3302),
#  ('Fred', 'Fred', 1, 3309),
#  ('G_G', '????', 2, 3314),
#  ('G_G', 'G_G', 2, 3314),
#  ('Prince of Excrement', 'Prince of Excrement', 1, 3323),
#  ('RBLR.dany fuckin heatley', 'RBLR.Marcutio', 2, 3332),
#  ('RBLR.dany fuckin heatley', 'RBLR.dany fuckin heatley', 2, 3332),
#  ('RBLR.dany fuckin heatley', 'Rick Sanchez', 2, 3332),
#  ('No', 'No', 2, 3333),
#  ('John Cena', 'John Cena', 2, 3351),
#  ('Rick Sanchez', 'Rick Sanchez', 1, 3359),
#  ('JMT', 'JMT', 3, 3368),
#  ('JMT', 'Jason', 3, 3368),
#  ('JMT', 'Light', 3, 3368),
#  ('Feelsbadman', 'Feelsbadman', 1, 3379),
#  ('Deodorant spray', 'Deodorant spray', 3, 3380),
#  ('Deodorant spray', 'TheGentleman', 3, 3380),
#  ('Ez', 'Ez', 8, 3391),
#  ('Ez', 'No more heroes', 8, 3391),
#  ('Hakuna Matata', 'Hakuna Matata', 3, 3397),
#  ('Hakuna Matata', 'TINKLES', 3, 3397),
#  ('Thomas The Dank Engine', 'Dall', 1, 3407),
#  ('Thomas The Dank Engine', 'Thomas The Dank Engine', 1, 3407),
#  ('DeeB', 'DeeB', 1, 3421),
#  ('OnePunchMan', 'OnePunchMan', 1, 3428),
#  ('OnePunchMan', 'twitch.tv/HaroldAgas17', 1, 3428),
#  ('Bob Ross', 'Bob Ross', 1, 3430),
#  ('Pablo Escobar', '22sjpog', 1, 3434),
#  ('Pablo Escobar', 'Pablo Escobar', 1, 3434),
#  ('Good Vibrations', 'Good Vibrations', 4, 3452),
#  ('brodericoh', 'brodericoh', 2, 3454),
#  ('HARRI$', 'HARRI$', 1, 3506),
#  ('HARRI$', 'TED', 1, 3506),
#  ('Onions123', 'Onions123', 1, 3511),
#  ('Onions123', 'kellyMONKEYS', 1, 3511),
#  ('nom', 'nom', 1, 3512),
#  ('Boobs-chan', 'Boobs-chan', 1, 3524),
#  ('Boobs-chan', 'Moe-Chan', 1, 3524),
#  ('Thomas The Dank Engine', 'Thomas The Dank Engine', 1, 3537),
#  ("Cau's Be's Hay's Sua's", "Cau's Be's Hay's Sua's", 1, 3542),
#  ('Salo', 'Salo', 3, 3543),
#  ('Kingslayer', 'Kingslayer', 2, 3544),
#  ('Kingslayer', 'Number Juan Doto Player', 2, 3544),
#  ('Kingslayer', 'Terpcasl', 2, 3544),
#  ('Fayher', 'Fayher', 1, 3573),
#  ('Fayher', 'JAFAR', 1, 3573),
#  ('322', '322', 1, 3574),
#  ('Jack', 'General Stonewall Jukeson', 2, 3583),
#  ('Jack', 'Jack', 2, 3583),
#  ('Jack', 'Martin Luther King Juker', 2, 3583),
#  ('RBLR.dany fuckin heatley', 'RBLR.dany fuckin heatley', 1, 3590),
#  ('RBLR.dany fuckin heatley', 'Rick Sanchez', 1, 3590),
#  ('~rabtug-molhut', '~rabtug-molhut', 1, 3595),
#  ('Good Vibrations', 'Good Vibrations', 3, 3603),
#  ('0.0', '0.0', 1, 3610),
#  ('.', '.', 1, 3620),
#  ('.', 'Alpha', 1, 3620),
#  ('Feelsbadman', 'Feelsbadman', 1, 3634),
#  ('Feelsbadman', 'Michael', 1, 3634),
#  ('Feelsbadman', 'ndlz', 1, 3634),
#  ('Moe-Chan', 'Boobs-chan', 1, 3660),
#  ('Moe-Chan', 'Moe-Chan', 1, 3660),
#  ('MHA | BlazinBoot', 'MHA | BlazinBoot', 1, 3663),
#  ('Matthew', 'Gates', 1, 3681),
#  ('Matthew', 'Matthew', 1, 3681),
#  ('Clueless', 'Clueless', 2, 3695),
#  ('Clueless', 'Virus', 2, 3695),
#  ('pyrofrantic', 'pyrofrantic', 1, 3704),
#  ('@hiro', '@hiro', 1, 3715),
#  ('@hiro', 'kk', 1, 3715),
#  ('Alpha', 'Alpha', 1, 3722),
#  ('Alpha', 'Zero', 1, 3722),
#  ('Mottley', 'Mottley', 1, 3725),
#  ('Mottley', 'VdoubleI', 1, 3725),
#  ('Number Juan Doto Player', '420 booty wizard', 2, 3727),
#  ('Number Juan Doto Player', 'Number Juan Doto Player', 2, 3727),
#  ('Number Juan Doto Player', 'Terpcasl', 2, 3727),
#  ('confessor', 'Gates', 1, 3728),
#  ('confessor', 'confessor', 1, 3728),
#  ('Snipe Desu~', 'Midnight', 4, 3731),
#  ('Snipe Desu~', 'Snipe Desu~', 4, 3731),
#  ('TINKLES', 'Black Jesus', 1, 3734),
#  ('TINKLES', 'Flash', 1, 3734),
#  ('TINKLES', 'TINKLES', 1, 3734),
#  ('.', '.', 1, 3760),
#  ('R.I.E.Eheroduelist', 'R.I.E.Eheroduelist', 1, 3773),
#  ('Do --', 'Do --', 1, 3780),
#  ('Do --', 'Madness', 1, 3780),
#  ('IceFraud', 'IceFraud', 1, 3782),
#  ('The Emperor', 'The Emperor', 1, 3787),
#  ('Angry Nikolai', 'Angry Nikolai', 1, 3798),
#  ('#ano.Ainsley Kek', '#ano.Ainsley Kek', 1, 3803),
#  ('RL', 'RL', 1, 3811),
#  ('SA!NT', 'SA!NT', 1, 3812),
#  ('Hope', 'Hope', 1, 3814),
#  ('Hope', 'ausoi', 1, 3814),
#  ('shibui', 'shibui', 4, 3819),
#  ('pLuhhmm', 'pLuhhmm', 7, 3823),
#  ('aaron', 'aaron', 1, 3825),
#  ('Link', 'Link', 4, 3842),
#  ('--', '--', 1, 3844),
#  ('VALAR MORGHULIS', 'VALAR MORGHULIS', 2, 3846),
#  ('KappaPride', 'Hard Mode', 1, 3861),
#  ('KappaPride', 'KappaPride', 1, 3861),
#  ('中國努力DOTA', '中國努力DOTA', 2, 3870),
#  ('Agressif', 'Agressif', 1, 3877),
#  ('Spazzkid', 'Spazzkid', 1, 3892),
#  ('Hansi', 'EXCLUSIVE', 2, 3897),
#  ('Hansi', 'Hansi', 2, 3897),
#  ('400 Lux', '400 Lux', 1, 3906),
#  ('IamThor', 'IamThor', 2, 3910),
#  ('Carlos', 'Carlos', 2, 3912),
#  ('Carlos', 'zzz', 2, 3912),
#  ('pLuhhmm', 'pLuhhmm', 3, 3913),
#  ('Urist', 'Urist', 1, 3925),
#  ('Alex', 'Alex', 2, 3927),
#  ('Alex', 'Fly', 2, 3927),
#  ('ATC', 'ATC', 1, 3929),
#  ('Clueless', 'Clueless', 3, 3930),
#  ('Greed', '322', 2, 3944),
#  ('Greed', 'Greed', 2, 3944),
#  ('HULK', 'HULK', 2, 3945),
#  ('HULK', 'TinkerBell', 2, 3945),
#  ('see me now', 'see me now', 3, 3952),
#  ('Cutie Kitty Sylveon x', 'Cutie Kitty Sylveon x', 1, 3961),
#  ('<3', '<3', 2, 3969),
#  ('VALAR MORGHULIS', 'VALAR MORGHULIS', 4, 3972),
#  ('Standin.ragha', 'Defensif^', 1, 3986),
#  ('Standin.ragha', 'Standin.ragha', 1, 3986),
#  ('Eosin', 'ATC', 3, 4004),
#  ('Eosin', 'Eosin', 3, 4004),
#  ('Big Dick Bandit', 'Big Dick Bandit', 2, 4009),
#  ('Carlos', 'Carlos', 1, 4013),
#  ('Angry Nikolai', 'Angry Nikolai', 2, 4017),
#  ('Angry Nikolai', 'Times_red', 2, 4017),
#  ('22', '22', 4, 4020),
#  ('HULK', '-_-', 3, 4021),
#  ('HULK', 'HULK', 3, 4021),
#  ('HULK', 'TinkerBell', 3, 4021),
#  ('??', '??', 1, 4031),
#  ('??', 'Skayl', 1, 4031),
#  ('Pepe Investor', 'Pepe Investor', 4, 4034),
#  ('Pepe Investor', 'X', 4, 4034),
#  ('(have fun, pal)', '(have fun, pal)', 2, 4045),
#  ('(have fun, pal)', '??', 2, 4045),
#  ('(have fun, pal)', '?????', 2, 4045),
#  ('Reaper', 'Cutie Kitty Sylveon x', 1, 4084),
#  ('Reaper', 'Reaper', 1, 4084),
#  ('The Dude', 'The Dude', 3, 4085),
#  ('Snipe Desu~', 'Snipe Desu~', 1, 4102),
#  ('Vern Vandamn', '777', 1, 4103),
#  ('Vern Vandamn', 'Vern Vandamn', 1, 4103),
#  ('Shacklz', 'Drake', 2, 4106),
#  ('Shacklz', 'Shacklz', 2, 4106),
#  ('Deez_Nuts', 'Deez_Nuts', 2, 4112),
#  ('Mortal Vengeance', 'Mortal Vengeance', 1, 4124),
#  ('Dracula', 'Dracula', 1, 4136),
#  ('ausoi', 'ausoi', 2, 4141),
#  ('HULK', 'HULK', 4, 4142),
#  ('HULK', 'TinkerBell', 4, 4142),
#  ('DotP.Kimmbbreelll', 'DotP.Kimmbbreelll', 5, 4164),
#  ('KKK', 'KKK', 1, 4169),
#  ('KKK', 'Valar Morghulis', 1, 4169),
#  ('Awesome', 'Awesome', 1, 4171),
#  ('Josh', 'Josh', 3, 4176),
#  ('777', '777', 1, 4178),
#  ('noob', 'noob', 1, 4182),
#  ('Bob Ross', 'Bob Ross', 1, 4186),
#  ('MeerCat', 'MeerCat', 3, 4190),
#  ('Unknown Content', 'Unknown Content', 1, 4191),
#  ('Gucci MagiK', 'Gucci MagiK', 3, 4199),
#  ('Hello', 'Hello', 1, 4200),
#  ('Hello', 'Ooze | hitbox.tv/oozex', 1, 4200),
#  ('$420', '$420', 1, 4206),
#  ('Aeon', 'Aeon', 5, 4211),
#  ('pls nerf kaski', 'pls nerf kaski', 1, 4218),
#  ('Fluffy', 'Fluffy', 5, 4220),
#  ('SSF', 'SSF', 2, 4234),
#  ('Baba Yaga', '< blank >', 1, 4246),
#  ('Baba Yaga', 'Baba Yaga', 1, 4246),
#  ('Baba Yaga', 'Ephemeral', 1, 4246),
#  ('Baba Yaga', 'Hachiko', 1, 4246),
#  ('sojtucker', 'sojtucker', 2, 4249),
#  ('$420', '$420', 1, 4259),
#  ('Tzu', 'Tzu', 3, 4260),
#  ('Tzu', 'ggwp', 3, 4260),
#  ("[EE's Disciple]", 'Lord', 3, 4264),
#  ("[EE's Disciple]", "[EE's Disciple]", 3, 4264),
#  ('居家男人', '居家男人', 2, 4284),
#  ('asdf', 'asdf', 2, 4291),
#  ('asdf', 'wizn', 2, 4291),
#  ('CHI LONG QUA', 'CHI LONG QUA', 2, 4296),
#  ('modjas', 'modjas', 2, 4301),
#  ('ThaddeusV', 'ThaddeusV', 1, 4303),
#  ('Phoenix', 'Phoenix', 1, 4310),
#  ('WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW', 'Scrotes', 2, 4312),
#  ('WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW',
#   'WWWWWWWWWWWWWWWWWWWWWWWWWWWWWWW',
#   2,
#   4312),
#  ('Nijbu', 'Nijbu', 1, 4317),
#  ('Gucci MagiK', 'Gucci MagiK', 1, 4318),
#  ('Schlebben.XD', 'Schlebben.XD', 1, 4363),
#  ('Schlebben.XD', 'Spooderman', 1, 4363),
#  ('Dracula', 'Dracula', 1, 4367),
#  ('Rampage', 'Rampage', 1, 4371),
#  ('The Seven Deadly Sins', 'The Seven Deadly Sins', 1, 4376),
#  ('noob :3', 'noob :3', 1, 4391),
#  ('Sindor', '???????', 1, 4406),
#  ('Sindor', 'Sindor', 1, 4406),
#  ('Jim Carry', 'Gucci MagiK', 1, 4408),
#  ('Jim Carry', 'Jim Carry', 1, 4408),
#  ('Jim Carry', 'Kappa', 1, 4408),
#  ('Vendetta', 'Vendetta', 1, 4412),
#  ('LoL', 'LoL', 1, 4413),
#  ('Mortal Vengeance', 'Mortal Vengeance', 6, 4422),
#  ('jaynanners', 'jaynanners', 7, 4425),
#  ('jaynanners', 'x-0ne (G.O.D)', 7, 4425),
#  ('Lumos', 'Lumos', 1, 4427),
#  ('MingLee', 'MingLee', 1, 4433),
#  ('Mirakuru', 'Mirakuru', 1, 4437),
#  (':D', ':D', 3, 4464),
#  (':D', 'Shacklz', 3, 4464),
#  ('CHI LONG QUA', 'CHI LONG QUA', 1, 4480),
#  ('baKKhus', 'baKKhus', 2, 4490),
#  ('leasey^', 'leasey^', 1, 4491),
#  ('Unknown', 'Unknown', 2, 4495),
#  ('Unknown', 'VALAR MORGHULIS', 2, 4495),
#  ('Unknown', 'X', 2, 4495),
#  ('Emil', 'Emil', 14, 4511),
#  ('Emil', 'twitch.tv/wingbladedota', 14, 4511),
#  ('Scrotes', 'Scrotes', 1, 4515),
#  ('Scrotes', 'Vigoss', 1, 4515),
#  ('Apple', 'Apple', 1, 4516),
#  ('Apple', 'Dracula', 1, 4516),
#  ('YOLO', 'YOLO', 1, 4520),
#  ('BigEyesShortCock', '......', 2, 4523),
#  ('BigEyesShortCock', 'BigEyesShortCock', 2, 4523),
#  ('Tobeh', 'Tobeh', 1, 4528),
#  ('o_O', 'o_O', 1, 4534),
#  ('...', '...', 1, 4538),
#  ('KAPPA', 'KAPPA', 1, 4541),
#  ('D.', 'D.', 3, 4568),
#  ('D.', 'xd', 3, 4568),
#  ('Justice', 'Justice', 1, 4573),
#  ('居家男人', '居家男人', 1, 4583),
#  ('RFA', 'Deadpool', 2, 4605),
#  ('RFA', 'RFA', 2, 4605),
#  ('RFA', 'dotato', 2, 4605),
#  ('CHI LONG QUA', 'CHI LONG QUA', 3, 4610),
#  ('CHI LONG QUA', 'o_O', 3, 4610),
#  ('never lucky BabyRage', 'never lucky BabyRage', 1, 4617),
#  ('Kappa', 'Kappa', 2, 4630),
#  ('Kappa', '^^', 2, 4630),
#  ('FREDRIK', 'Cringer', 1, 4631),
#  ('FREDRIK', 'FREDRIK', 1, 4631),
#  ('Emil', 'Emil', 2, 4639),
#  ('Emil', 'James', 2, 4639),
#  ('KappaRoss', 'KappaRoss', 1, 4644),
#  ('JohnDoe', 'GenghisLOL', 4, 4654),
#  ('JohnDoe', 'JohnDoe', 4, 4654),
#  ('Ares', 'Ares', 3, 4666),
#  ('333', '333', 3, 4667),
#  ('LoL', 'LoL', 1, 4674),
#  ('LoL', 'Mirakuru', 1, 4674),
#  ('Nigga', 'Nigga', 1, 4686),
#  ('WaaDaaFaak!?', 'WaaDaaFaak!?', 3, 4688),
#  ('william.boshi', 'william.boshi', 1, 4694),
#  ('Rorschach', 'Rorschach', 1, 4704),
#  ('lungs', 'lungs', 3, 4712),
#  ('Goofy Hell', '.inf', 1, 4720),
#  ('Goofy Hell', 'Goofy Hell', 1, 4720),
#  ('Goofy Hell', 'KMZWAY87AA', 1, 4720),
#  ('Goofy Hell', 'Lost_Faith', 1, 4720),
#  ('Goofy Hell', '[N]ooble', 1, 4720),
#  ('Jesus', 'Frost', 16, 4734),
#  ('Jesus', 'Jesus', 16, 4734),
#  ('MIE', 'MIE', 1, 4735),
#  ('Alive', 'Alive', 4, 4738),
#  ('Alive', 'gibe da Weekend, b0ss', 4, 4738),
#  ('[DoGe]Lopaha', '[DoGe]Lopaha', 1, 4740),
#  ('Viridian', 'Viridian', 1, 4744),
#  ('peco', 'peco', 1, 4753),
#  ('peco', '✿ sk_Baymax™♠', 1, 4753),
#  ('Smaug', 'Smaug', 1, 4754),
#  ('333', '333', 1, 4757),
#  ('333', 'Saltz', 1, 4757),
#  ('333', 'bourgeoisie', 1, 4757),
#  ('BiG BaNaNna !', 'BiG BaNaNna !', 1, 4760),
#  ('BuRN', 'BuRN', 2, 4774),
#  ('BuRN', 'PANDA', 2, 4774),
#  ('U OK NERD?', 'U OK NERD?', 1, 4778),
#  ('Sara :)', 'MrMkay', 1, 4785),
#  ('Sara :)', 'Sara :)', 1, 4785),
#  ('Firefix', 'Firefix', 2, 4786),
#  ('Ravushimo', 'Ravushimo', 2, 4794),
#  ('Mayhem', '@builder_247', 8, 4802),
#  ('Mayhem', 'Mayhem', 8, 4802),
#  ('[DoGe]Lopaha', '[DoGe]Lopaha', 1, 4829),
#  ('Chill', 'Chill', 3, 4833),
#  ('bourgeoisie', 'Saltz', 1, 4839),
#  ('bourgeoisie', 'bourgeoisie', 1, 4839),
#  ('V', 'V', 4, 4852),
#  ('[KIP] rickert', '[KIP] rickert', 1, 4861),
#  ('Play it again Sam', 'Play it again Sam', 5, 4862),
#  ('Recovery', 'Andy', 1, 4869),
#  ('Recovery', 'Recovery', 1, 4869),
#  ('Recovery', 'Zeeks', 1, 4869),
#  ('AzoR725', 'AzoR725', 1, 4875),
#  ('CRUMBLING', 'CRUMBLING', 1, 4887),
#  ('Brerik', 'Brerik', 1, 4892),
#  ('Miley', 'Miley', 1, 4900),
#  ('JOHN HITLER', 'JOHN HITLER', 2, 4915),
#  ('JOHN HITLER', 'King Wizard', 2, 4915),
#  ('Flipt', '13', 1, 4925),
#  ('Flipt', 'Flipt', 1, 4925),
#  ('9/10', '9/10', 1, 4932),
#  ('L30N', 'L30N', 1, 4940),
#  ('L30N', 'Mango', 1, 4940),
#  ('asd', 'asd', 1, 4942),
#  ('Arothe. /muted all', 'Arothe. /muted all', 3, 4948),
#  ('Ya', 'Ace', 1, 4963),
#  ('Ya', 'Ya', 1, 4963),
#  ('Ya', '`Blurry Eyes', 1, 4963),
#  ('AzoR725', 'AzoR725', 3, 4982),
#  ('Play it again Sam', 'Play it again Sam', 6, 4991),
#  ('Сын Собаки', 'Сын Собаки', 3, 5002),
#  ('emge', 'emge', 1, 5018),
#  ('YOLO', 'YOLO', 1, 5063),
#  ('YOLO', 'rKaiser', 1, 5063),
#  ('Up-iN*tHe.AiR', 'Derp Derp', 2, 5064),
#  ('Up-iN*tHe.AiR', 'Ragnar', 2, 5064),
#  ('Up-iN*tHe.AiR', 'Up-iN*tHe.AiR', 2, 5064),
#  ('RyuKen', 'RyuKen', 2, 5082),
#  ('Pineapplefruitdude', 'Pineapplefruitdude', 2, 5087),
#  ('pitzuuu', '17', 1, 5090),
#  ('pitzuuu', 'Mr. Meeseeks', 1, 5090),
#  ('pitzuuu', 'pitzuuu', 1, 5090),
#  ('Sorry', 'Sorry', 1, 5104),
#  ('?????', '?????', 1, 5118),
#  ('SQWERTY', 'SQWERTY', 1, 5120),
#  ('The Seven Deadly Sins', 'The Seven Deadly Sins', 2, 5125),
#  ('Skayl', 'Skayl', 1, 5130),
#  ('leviosaw', 'GGWP', 1, 5132),
#  ('leviosaw', 'leviosaw', 1, 5132),
#  ('Hero', 'Hero', 1, 5142),
#  ('Hero', 'nitoma', 1, 5142),
#  ('RomanAbbasid', 'RomanAbbasid', 3, 5146),
#  ('Carnage', 'Carnage', 1, 5160),
#  ('Sartre', 'LOL', 1, 5161),
#  ('Sartre', 'Sartre', 1, 5161),
#  ('Sam', 'Sam', 1, 5164),
#  ('Сын Собаки', 'Сын Собаки', 1, 5191),
#  ('Joker', 'Joker', 1, 5210),
#  ('Player', 'M', 1, 5211),
#  ('Player', 'Player', 1, 5211),
#  ('Player', 'WaaDaaFaak!?', 1, 5211),
#  ('Player', 'X', 1, 5211),
#  ('~rabtug-molhut', '~rabtug-molhut', 1, 5223),
#  ('[DG]Hoppen', '[DG]Hoppen', 1, 5225),
#  ('Derp Derp', 'Derp Derp', 1, 5239),
#  ('Derp Derp', 'Ragnar', 1, 5239),
#  ('Derp Derp', 'Up-iN*tHe.AiR', 1, 5239),
#  ('Ice.in.your.eyeS', '3^!|', 1, 5248),
#  ('Ice.in.your.eyeS', 'Ice.in.your.eyeS', 1, 5248),
#  ('Capital Control', 'Capital Control', 1, 5265),
#  ('wpt', 'wpt', 1, 5272),
#  ('Moongazer', 'Moongazer', 1, 5274),
#  ('@KossDota', '@KossDota', 5, 5281),
#  ('Sartre', '123', 1, 5295),
#  ('Sartre', 'Sartre', 1, 5295),
#  ('AzoR725', 'AzoR725', 1, 5306),
#  ('Tg den Storslåede Troldkarl!', 'Tg den Storslåede Troldkarl!', 1, 5313),
#  ('King Wizard', 'JOHN HITLER', 4, 5314),
#  ('King Wizard', 'King Wizard', 4, 5314),
#  ('MingLee', 'MingLee', 1, 5333),
#  ('MingLee', 'qwe', 1, 5333),
#  ('111', '111', 1, 5338),
#  ('111', '???', 1, 5338),
#  ('Bob Ross', 'Bob Ross', 1, 5360),
#  ('Skeleton Coast', 'Skeleton Coast', 1, 5367),
#  ('Tony', 'Tony', 1, 5370),
#  ('Alex', 'Alex', 4, 5383),
#  ('Сын Собаки', 'Kaiser', 2, 5388),
#  ...]

# %% [markdown]
# ### Reshape into dataframe

# %%
freq_user_df = pd.DataFrame(df_freq_draft, columns = ['source', 'target', 'weight', 'match'])

# %% [markdown]
# ### Delete data with the same source and target

# %%
freq_user_df = freq_user_df.loc[freq_user_df['source']!= freq_user_df['target']]

# %% [markdown]
# #### Add column `type`, the type of network

# %%
freq_user_df['type'] = 'Directed'

# %%
freq_user_df.to_csv('../data/chat_sna_shaped.csv', index = False)
